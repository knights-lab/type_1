# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import seaborn as sns

from scipy.stats import pearsonr

sns.set_style("darkgrid")
np.random.seed(930525)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 200)

warnings.simplefilter('once')

# %matplotlib inline
# %load_ext watermark
# %watermark --iversions
# Out:
# numpy   1.18.4
# seaborn 0.10.1
# pandas  1.0.4

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import plot_roc_curve
from sklearn.ensemble import RandomForestClassifier
import shap

import pandas as pd
import requests

from io import StringIO
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
from collections import defaultdict
from glob import glob

url = requests.get('https://docs.google.com/spreadsheets/d/1xqhFLsQplNUu5k9Uxv7DgTwftCiE78E0JmsKvNi0Ft4/export?format=csv')
csv_raw = StringIO(url.text)
df_truth = pd.read_csv(csv_raw)

inf_tax_file = "/mnt/btrfs/data/rep202/ab/taxmap.tsv"

# %%
dd = defaultdict(set)
dd_species = defaultdict(set)
for t in df_truth.itertuples():
    query = t.homotypic_synonym
    results = !rg {query} {inf_tax_file}
    if len(results) > 0:
        for r in results:
            split = r.split("\t")
            dd[t.dataset].add(split[0])
            dd_species[t.dataset].add(";".join(split[1].split(";")[:7]))

# %%
df_tax = pd.read_csv(inf_tax_file, names=["assembly_accession", "tax"], sep="\t")

df_tax["species"] = [";".join(_.split(";")[:7]) for _ in df_tax.tax]
df_tax["genus"] = [";".join(_.split(";")[:6]) for _ in df_tax.tax]
df_tax["family"] = [";".join(_.split(";")[:5]) for _ in df_tax.tax]

# %%
from glob import glob
import os

basepath = "/mnt/btrfs/data/type_1/species_mc"
dirs = [d for d in os.listdir(basepath) if os.path.isdir(os.path.join(basepath, d))]

# dual_index failed
dirs.remove('dual_index')

# %%
dfs = []
for directory in dirs:
    df = pd.read_csv(os.path.join(basepath, directory, 'filter', 't1.coverage.r202.txt'), index_col = 0)
    df['dataset'] = directory
    dfs.append(df)
    
df_type_1_features = pd.concat(dfs)

# %%
dfs = []
for directory in dirs:
    df = pd.read_csv(os.path.join(basepath, directory, 'filter', 'shogun.capitalist.r202.txt'), index_col = None, sep="\t")
    cols = list(df.columns)
    cols[0] = "tax"
    cols[1] = "hits"
    df.columns = cols

    df = df.loc[:, df.columns.difference(cols[2:])]
    df["dataset"] = directory
    df["relative_abundace"] = df.hits / df.hits.sum()
    dfs.append(df)    
df_capitalist_species = pd.concat(dfs)
df_capitalist_species["species"] = [";".join(_.split(";")[:7]) for _ in df_capitalist_species.tax]

# %%
rows = []
for t in df_type_1_features.itertuples():
    if t.assembly_accession in dd[t.dataset]:
        rows.append(True)
    else:
        rows.append(False)
df_type_1_features["truth"] = rows

# %%
rows = []
for t in df_capitalist_species.itertuples():
    if t.species in dd_species[t.dataset]:
        rows.append(True)
    else:
        rows.append(False)
df_capitalist_species["truth"] = rows

# %%
df_strain
# Out:
#       consecutive_ns  expected_coverage  gc_content  genome_length  hits  \
# 0                 20           0.000026    0.414288        3878815     1
# 1                  0           0.000068    0.379810        2944528     2
# 2                 20           0.000032    0.499116        3145619     1
# 3                  0           0.000039    0.327075        2559946     1
# 4                  0           0.000037    0.415740        2751104     1
# ...              ...                ...         ...            ...   ...
# 3573            5374           0.000000    0.501281        4233403     1
# 3574             209           0.000020    0.528278        4777115     1
# 3575              87           0.000019    0.660620        3992575     1
# 3576              20           0.000030    0.309583        2876197     1
# 3577            1595           0.000025    0.398582        2910102     1
#
#       largest_pileup  num_n_groups  percent_coverage  \
# 0                  1             1      1.489624e+11
# 1                  1             0      4.335123e+10
# 2                  1            15      9.796949e+10
# 3                  1             0      6.488439e+10
# 4                  1             0      7.493637e+10
# ...              ...           ...               ...
# 3573               0           331               inf
# 3574               1           201      2.352663e+11
# 3575               1            55      2.154143e+11
# 3576               1            74      9.732364e+10
# 3577               1            36      1.176207e+11
#
#       percent_max_uncovered_region  percent_padded_coverage
# 0                         0.999974             7.522603e+10
# 1                         0.591208             2.167561e+10
# 2                         0.999968             4.947459e+10
# 3                         0.999961             3.276662e+10
# 4                         0.999963             3.784287e+10
# ...                            ...                      ...
# 3573                      2.000000             1.792170e+11
# 3574                      0.999980             1.141041e+11
# 3575                      0.999981             7.970328e+10
# 3576                      0.999970             4.136255e+10
# 3577                      0.999975             4.234347e+10
#
# [63663 rows x 10 columns]

# %%
# !ls {basepath_sim}
# Out:
# gis_20.0.10.b6			    t1.coverage.hmp_even.4.1000000.txt
# gis_20.0.100.b6			    t1.coverage.hmp_even.5.10.log
# gis_20.0.1000.b6		    t1.coverage.hmp_even.5.10.txt
# gis_20.0.10000.b6		    t1.coverage.hmp_even.5.100.log
# gis_20.0.100000.b6		    t1.coverage.hmp_even.5.100.txt
# gis_20.0.1000000.b6		    t1.coverage.hmp_even.5.1000.log
# gis_20.1.10.b6			    t1.coverage.hmp_even.5.1000.txt
# gis_20.1.100.b6			    t1.coverage.hmp_even.5.10000.log
# gis_20.1.1000.b6		    t1.coverage.hmp_even.5.10000.txt
# gis_20.1.10000.b6		    t1.coverage.hmp_even.5.100000.log
# gis_20.1.100000.b6		    t1.coverage.hmp_even.5.100000.txt
# gis_20.1.1000000.b6		    t1.coverage.hmp_even.5.1000000.log
# gis_20.2.10.b6			    t1.coverage.hmp_even.5.1000000.txt
# gis_20.2.100.b6			    t1.coverage.hmp_even.6.10.log
# gis_20.2.1000.b6		    t1.coverage.hmp_even.6.10.txt
# gis_20.2.10000.b6		    t1.coverage.hmp_even.6.100.log
# gis_20.2.100000.b6		    t1.coverage.hmp_even.6.100.txt
# gis_20.2.1000000.b6		    t1.coverage.hmp_even.6.1000.log
# gis_20.3.10.b6			    t1.coverage.hmp_even.6.1000.txt
# gis_20.3.100.b6			    t1.coverage.hmp_even.6.10000.log
# gis_20.3.1000.b6		    t1.coverage.hmp_even.6.10000.txt
# gis_20.3.10000.b6		    t1.coverage.hmp_even.6.100000.log
# gis_20.3.100000.b6		    t1.coverage.hmp_even.6.100000.txt
# gis_20.3.1000000.b6		    t1.coverage.hmp_even.6.1000000.log
# gis_20.4.10.b6			    t1.coverage.hmp_even.6.1000000.txt
# gis_20.4.100.b6			    t1.coverage.hmp_even.7.10.log
# gis_20.4.1000.b6		    t1.coverage.hmp_even.7.10.txt
# gis_20.4.10000.b6		    t1.coverage.hmp_even.7.100.log
# gis_20.4.100000.b6		    t1.coverage.hmp_even.7.100.txt
# gis_20.4.1000000.b6		    t1.coverage.hmp_even.7.1000.log
# gis_20.5.10.b6			    t1.coverage.hmp_even.7.1000.txt
# gis_20.5.100.b6			    t1.coverage.hmp_even.7.10000.log
# gis_20.5.1000.b6		    t1.coverage.hmp_even.7.10000.txt
# gis_20.5.10000.b6		    t1.coverage.hmp_even.7.100000.log
# gis_20.5.100000.b6		    t1.coverage.hmp_even.7.100000.txt
# gis_20.5.1000000.b6		    t1.coverage.hmp_even.7.1000000.log
# gis_20.6.10.b6			    t1.coverage.hmp_even.7.1000000.txt
# gis_20.6.100.b6			    t1.coverage.hmp_even.8.10.log
# gis_20.6.1000.b6		    t1.coverage.hmp_even.8.10.txt
# gis_20.6.10000.b6		    t1.coverage.hmp_even.8.100.log
# gis_20.6.100000.b6		    t1.coverage.hmp_even.8.100.txt
# gis_20.6.1000000.b6		    t1.coverage.hmp_even.8.1000.log
# gis_20.7.10.b6			    t1.coverage.hmp_even.8.1000.txt
# gis_20.7.100.b6			    t1.coverage.hmp_even.8.10000.log
# gis_20.7.1000.b6		    t1.coverage.hmp_even.8.10000.txt
# gis_20.7.10000.b6		    t1.coverage.hmp_even.8.100000.log
# gis_20.7.100000.b6		    t1.coverage.hmp_even.8.100000.txt
# gis_20.7.1000000.b6		    t1.coverage.hmp_even.8.1000000.log
# gis_20.8.10.b6			    t1.coverage.hmp_even.8.1000000.txt
# gis_20.8.100.b6			    t1.coverage.hmp_even.9.10.log
# gis_20.8.1000.b6		    t1.coverage.hmp_even.9.10.txt
# gis_20.8.10000.b6		    t1.coverage.hmp_even.9.100.log
# gis_20.8.100000.b6		    t1.coverage.hmp_even.9.100.txt
# gis_20.8.1000000.b6		    t1.coverage.hmp_even.9.1000.log
# gis_20.9.10.b6			    t1.coverage.hmp_even.9.1000.txt
# gis_20.9.100.b6			    t1.coverage.hmp_even.9.10000.log
# gis_20.9.1000.b6		    t1.coverage.hmp_even.9.10000.txt
# gis_20.9.10000.b6		    t1.coverage.hmp_even.9.100000.log
# gis_20.9.100000.b6		    t1.coverage.hmp_even.9.100000.txt
# gis_20.9.1000000.b6		    t1.coverage.hmp_even.9.1000000.log
# hmp_even.0.10.b6		    t1.coverage.hmp_even.9.1000000.txt
# hmp_even.0.100.b6		    t1.coverage.hmp_staggered.0.10.log
# hmp_even.0.1000.b6		    t1.coverage.hmp_staggered.0.10.txt
# hmp_even.0.10000.b6		    t1.coverage.hmp_staggered.0.100.log
# hmp_even.0.100000.b6		    t1.coverage.hmp_staggered.0.100.txt
# hmp_even.0.1000000.b6		    t1.coverage.hmp_staggered.0.1000.log
# hmp_even.1.10.b6		    t1.coverage.hmp_staggered.0.1000.txt
# hmp_even.1.100.b6		    t1.coverage.hmp_staggered.0.10000.log
# hmp_even.1.1000.b6		    t1.coverage.hmp_staggered.0.10000.txt
# hmp_even.1.10000.b6		    t1.coverage.hmp_staggered.0.100000.log
# hmp_even.1.100000.b6		    t1.coverage.hmp_staggered.0.100000.txt
# hmp_even.1.1000000.b6		    t1.coverage.hmp_staggered.0.1000000.log
# hmp_even.2.10.b6		    t1.coverage.hmp_staggered.0.1000000.txt
# hmp_even.2.100.b6		    t1.coverage.hmp_staggered.1.10.log
# hmp_even.2.1000.b6		    t1.coverage.hmp_staggered.1.10.txt
# hmp_even.2.10000.b6		    t1.coverage.hmp_staggered.1.100.log
# hmp_even.2.100000.b6		    t1.coverage.hmp_staggered.1.100.txt
# hmp_even.2.1000000.b6		    t1.coverage.hmp_staggered.1.1000.log
# hmp_even.3.10.b6		    t1.coverage.hmp_staggered.1.1000.txt
# hmp_even.3.100.b6		    t1.coverage.hmp_staggered.1.10000.log
# hmp_even.3.1000.b6		    t1.coverage.hmp_staggered.1.10000.txt
# hmp_even.3.10000.b6		    t1.coverage.hmp_staggered.1.100000.log
# hmp_even.3.100000.b6		    t1.coverage.hmp_staggered.1.100000.txt
# hmp_even.3.1000000.b6		    t1.coverage.hmp_staggered.1.1000000.log
# hmp_even.4.10.b6		    t1.coverage.hmp_staggered.1.1000000.txt
# hmp_even.4.100.b6		    t1.coverage.hmp_staggered.2.10.log
# hmp_even.4.1000.b6		    t1.coverage.hmp_staggered.2.10.txt
# hmp_even.4.10000.b6		    t1.coverage.hmp_staggered.2.100.log
# hmp_even.4.100000.b6		    t1.coverage.hmp_staggered.2.100.txt
# hmp_even.4.1000000.b6		    t1.coverage.hmp_staggered.2.1000.log
# hmp_even.5.10.b6		    t1.coverage.hmp_staggered.2.1000.txt
# hmp_even.5.100.b6		    t1.coverage.hmp_staggered.2.10000.log
# hmp_even.5.1000.b6		    t1.coverage.hmp_staggered.2.10000.txt
# hmp_even.5.10000.b6		    t1.coverage.hmp_staggered.2.100000.log
# hmp_even.5.100000.b6		    t1.coverage.hmp_staggered.2.100000.txt
# hmp_even.5.1000000.b6		    t1.coverage.hmp_staggered.2.1000000.log
# hmp_even.6.10.b6		    t1.coverage.hmp_staggered.2.1000000.txt
# hmp_even.6.100.b6		    t1.coverage.hmp_staggered.3.10.log
# hmp_even.6.1000.b6		    t1.coverage.hmp_staggered.3.10.txt
# hmp_even.6.10000.b6		    t1.coverage.hmp_staggered.3.100.log
# hmp_even.6.100000.b6		    t1.coverage.hmp_staggered.3.100.txt
# hmp_even.6.1000000.b6		    t1.coverage.hmp_staggered.3.1000.log
# hmp_even.7.10.b6		    t1.coverage.hmp_staggered.3.1000.txt
# hmp_even.7.100.b6		    t1.coverage.hmp_staggered.3.10000.log
# hmp_even.7.1000.b6		    t1.coverage.hmp_staggered.3.10000.txt
# hmp_even.7.10000.b6		    t1.coverage.hmp_staggered.3.100000.log
# hmp_even.7.100000.b6		    t1.coverage.hmp_staggered.3.100000.txt
# hmp_even.7.1000000.b6		    t1.coverage.hmp_staggered.3.1000000.log
# hmp_even.8.10.b6		    t1.coverage.hmp_staggered.3.1000000.txt
# hmp_even.8.100.b6		    t1.coverage.hmp_staggered.4.10.log
# hmp_even.8.1000.b6		    t1.coverage.hmp_staggered.4.10.txt
# hmp_even.8.10000.b6		    t1.coverage.hmp_staggered.4.100.log
# hmp_even.8.100000.b6		    t1.coverage.hmp_staggered.4.100.txt
# hmp_even.8.1000000.b6		    t1.coverage.hmp_staggered.4.1000.log
# hmp_even.9.10.b6		    t1.coverage.hmp_staggered.4.1000.txt
# hmp_even.9.100.b6		    t1.coverage.hmp_staggered.4.10000.log
# hmp_even.9.1000.b6		    t1.coverage.hmp_staggered.4.10000.txt
# hmp_even.9.10000.b6		    t1.coverage.hmp_staggered.4.100000.log
# hmp_even.9.100000.b6		    t1.coverage.hmp_staggered.4.100000.txt
# hmp_even.9.1000000.b6		    t1.coverage.hmp_staggered.4.1000000.log
# hmp_staggered.0.10.b6		    t1.coverage.hmp_staggered.4.1000000.txt
# hmp_staggered.0.100.b6		    t1.coverage.hmp_staggered.5.10.log
# hmp_staggered.0.1000.b6		    t1.coverage.hmp_staggered.5.10.txt
# hmp_staggered.0.10000.b6	    t1.coverage.hmp_staggered.5.100.log
# hmp_staggered.0.100000.b6	    t1.coverage.hmp_staggered.5.100.txt
# hmp_staggered.0.1000000.b6	    t1.coverage.hmp_staggered.5.1000.log
# hmp_staggered.1.10.b6		    t1.coverage.hmp_staggered.5.1000.txt
# hmp_staggered.1.100.b6		    t1.coverage.hmp_staggered.5.10000.log
# hmp_staggered.1.1000.b6		    t1.coverage.hmp_staggered.5.10000.txt
# hmp_staggered.1.10000.b6	    t1.coverage.hmp_staggered.5.100000.log
# hmp_staggered.1.100000.b6	    t1.coverage.hmp_staggered.5.100000.txt
# hmp_staggered.1.1000000.b6	    t1.coverage.hmp_staggered.5.1000000.log
# hmp_staggered.2.10.b6		    t1.coverage.hmp_staggered.5.1000000.txt
# hmp_staggered.2.100.b6		    t1.coverage.hmp_staggered.6.10.log
# hmp_staggered.2.1000.b6		    t1.coverage.hmp_staggered.6.10.txt
# hmp_staggered.2.10000.b6	    t1.coverage.hmp_staggered.6.100.log
# hmp_staggered.2.100000.b6	    t1.coverage.hmp_staggered.6.100.txt
# hmp_staggered.2.1000000.b6	    t1.coverage.hmp_staggered.6.1000.log
# hmp_staggered.3.10.b6		    t1.coverage.hmp_staggered.6.1000.txt
# hmp_staggered.3.100.b6		    t1.coverage.hmp_staggered.6.10000.log
# hmp_staggered.3.1000.b6		    t1.coverage.hmp_staggered.6.10000.txt
# hmp_staggered.3.10000.b6	    t1.coverage.hmp_staggered.6.100000.log
# hmp_staggered.3.100000.b6	    t1.coverage.hmp_staggered.6.100000.txt
# hmp_staggered.3.1000000.b6	    t1.coverage.hmp_staggered.6.1000000.log
# hmp_staggered.4.10.b6		    t1.coverage.hmp_staggered.6.1000000.txt
# hmp_staggered.4.100.b6		    t1.coverage.hmp_staggered.7.10.log
# hmp_staggered.4.1000.b6		    t1.coverage.hmp_staggered.7.10.txt
# hmp_staggered.4.10000.b6	    t1.coverage.hmp_staggered.7.100.log
# hmp_staggered.4.100000.b6	    t1.coverage.hmp_staggered.7.100.txt
# hmp_staggered.4.1000000.b6	    t1.coverage.hmp_staggered.7.1000.log
# hmp_staggered.5.10.b6		    t1.coverage.hmp_staggered.7.1000.txt
# hmp_staggered.5.100.b6		    t1.coverage.hmp_staggered.7.10000.log
# hmp_staggered.5.1000.b6		    t1.coverage.hmp_staggered.7.10000.txt
# hmp_staggered.5.10000.b6	    t1.coverage.hmp_staggered.7.100000.log
# hmp_staggered.5.100000.b6	    t1.coverage.hmp_staggered.7.100000.txt
# hmp_staggered.5.1000000.b6	    t1.coverage.hmp_staggered.7.1000000.log
# hmp_staggered.6.10.b6		    t1.coverage.hmp_staggered.7.1000000.txt
# hmp_staggered.6.100.b6		    t1.coverage.hmp_staggered.8.10.log
# hmp_staggered.6.1000.b6		    t1.coverage.hmp_staggered.8.10.txt
# hmp_staggered.6.10000.b6	    t1.coverage.hmp_staggered.8.100.log
# hmp_staggered.6.100000.b6	    t1.coverage.hmp_staggered.8.100.txt
# hmp_staggered.6.1000000.b6	    t1.coverage.hmp_staggered.8.1000.log
# hmp_staggered.7.10.b6		    t1.coverage.hmp_staggered.8.1000.txt
# hmp_staggered.7.100.b6		    t1.coverage.hmp_staggered.8.10000.log
# hmp_staggered.7.1000.b6		    t1.coverage.hmp_staggered.8.10000.txt
# hmp_staggered.7.10000.b6	    t1.coverage.hmp_staggered.8.100000.log
# hmp_staggered.7.100000.b6	    t1.coverage.hmp_staggered.8.100000.txt
# hmp_staggered.7.1000000.b6	    t1.coverage.hmp_staggered.8.1000000.log
# hmp_staggered.8.10.b6		    t1.coverage.hmp_staggered.8.1000000.txt
# hmp_staggered.8.100.b6		    t1.coverage.hmp_staggered.9.10.log
# hmp_staggered.8.1000.b6		    t1.coverage.hmp_staggered.9.10.txt
# hmp_staggered.8.10000.b6	    t1.coverage.hmp_staggered.9.100.log
# hmp_staggered.8.100000.b6	    t1.coverage.hmp_staggered.9.100.txt
# hmp_staggered.8.1000000.b6	    t1.coverage.hmp_staggered.9.1000.log
# hmp_staggered.9.10.b6		    t1.coverage.hmp_staggered.9.1000.txt
# hmp_staggered.9.100.b6		    t1.coverage.hmp_staggered.9.10000.log
# hmp_staggered.9.1000.b6		    t1.coverage.hmp_staggered.9.10000.txt
# hmp_staggered.9.10000.b6	    t1.coverage.hmp_staggered.9.100000.log
# hmp_staggered.9.100000.b6	    t1.coverage.hmp_staggered.9.100000.txt
# hmp_staggered.9.1000000.b6	    t1.coverage.hmp_staggered.9.1000000.log
# mbarc_26.0.10.b6		    t1.coverage.hmp_staggered.9.1000000.txt
# mbarc_26.0.100.b6		    t1.coverage.zymo_log.0.10.log
# mbarc_26.0.1000.b6		    t1.coverage.zymo_log.0.10.txt
# mbarc_26.0.10000.b6		    t1.coverage.zymo_log.0.100.log
# mbarc_26.0.100000.b6		    t1.coverage.zymo_log.0.100.txt
# mbarc_26.0.1000000.b6		    t1.coverage.zymo_log.0.1000.log
# mbarc_26.1.10.b6		    t1.coverage.zymo_log.0.1000.txt
# mbarc_26.1.100.b6		    t1.coverage.zymo_log.0.10000.log
# mbarc_26.1.1000.b6		    t1.coverage.zymo_log.0.10000.txt
# mbarc_26.1.10000.b6		    t1.coverage.zymo_log.0.100000.log
# mbarc_26.1.100000.b6		    t1.coverage.zymo_log.0.100000.txt
# mbarc_26.1.1000000.b6		    t1.coverage.zymo_log.0.1000000.log
# mbarc_26.2.10.b6		    t1.coverage.zymo_log.0.1000000.txt
# mbarc_26.2.100.b6		    t1.coverage.zymo_log.1.10.log
# mbarc_26.2.1000.b6		    t1.coverage.zymo_log.1.10.txt
# mbarc_26.2.10000.b6		    t1.coverage.zymo_log.1.100.log
# mbarc_26.2.100000.b6		    t1.coverage.zymo_log.1.100.txt
# mbarc_26.2.1000000.b6		    t1.coverage.zymo_log.1.1000.log
# mbarc_26.3.10.b6		    t1.coverage.zymo_log.1.1000.txt
# mbarc_26.3.100.b6		    t1.coverage.zymo_log.1.10000.log
# mbarc_26.3.1000.b6		    t1.coverage.zymo_log.1.10000.txt
# mbarc_26.3.10000.b6		    t1.coverage.zymo_log.1.100000.log
# mbarc_26.3.100000.b6		    t1.coverage.zymo_log.1.100000.txt
# mbarc_26.3.1000000.b6		    t1.coverage.zymo_log.1.1000000.log
# mbarc_26.4.10.b6		    t1.coverage.zymo_log.1.1000000.txt
# mbarc_26.4.100.b6		    t1.coverage.zymo_log.2.10.log
# mbarc_26.4.1000.b6		    t1.coverage.zymo_log.2.10.txt
# mbarc_26.4.10000.b6		    t1.coverage.zymo_log.2.100.log
# mbarc_26.4.100000.b6		    t1.coverage.zymo_log.2.100.txt
# mbarc_26.4.1000000.b6		    t1.coverage.zymo_log.2.1000.log
# mbarc_26.5.10.b6		    t1.coverage.zymo_log.2.1000.txt
# mbarc_26.5.100.b6		    t1.coverage.zymo_log.2.10000.log
# mbarc_26.5.1000.b6		    t1.coverage.zymo_log.2.10000.txt
# mbarc_26.5.10000.b6		    t1.coverage.zymo_log.2.100000.log
# mbarc_26.5.100000.b6		    t1.coverage.zymo_log.2.100000.txt
# mbarc_26.5.1000000.b6		    t1.coverage.zymo_log.2.1000000.log
# mbarc_26.6.10.b6		    t1.coverage.zymo_log.2.1000000.txt
# mbarc_26.6.100.b6		    t1.coverage.zymo_log.3.10.log
# mbarc_26.6.1000.b6		    t1.coverage.zymo_log.3.10.txt
# mbarc_26.6.10000.b6		    t1.coverage.zymo_log.3.100.log
# mbarc_26.6.100000.b6		    t1.coverage.zymo_log.3.100.txt
# mbarc_26.6.1000000.b6		    t1.coverage.zymo_log.3.1000.log
# mbarc_26.7.10.b6		    t1.coverage.zymo_log.3.1000.txt
# mbarc_26.7.100.b6		    t1.coverage.zymo_log.3.10000.log
# mbarc_26.7.1000.b6		    t1.coverage.zymo_log.3.10000.txt
# mbarc_26.7.10000.b6		    t1.coverage.zymo_log.3.100000.log
# mbarc_26.7.100000.b6		    t1.coverage.zymo_log.3.100000.txt
# mbarc_26.7.1000000.b6		    t1.coverage.zymo_log.3.1000000.log
# mbarc_26.8.10.b6		    t1.coverage.zymo_log.3.1000000.txt
# mbarc_26.8.100.b6		    t1.coverage.zymo_log.4.10.log
# mbarc_26.8.1000.b6		    t1.coverage.zymo_log.4.10.txt
# mbarc_26.8.10000.b6		    t1.coverage.zymo_log.4.100.log
# mbarc_26.8.100000.b6		    t1.coverage.zymo_log.4.100.txt
# mbarc_26.8.1000000.b6		    t1.coverage.zymo_log.4.1000.log
# mbarc_26.9.10.b6		    t1.coverage.zymo_log.4.1000.txt
# mbarc_26.9.100.b6		    t1.coverage.zymo_log.4.10000.log
# mbarc_26.9.1000.b6		    t1.coverage.zymo_log.4.10000.txt
# mbarc_26.9.10000.b6		    t1.coverage.zymo_log.4.100000.log
# mbarc_26.9.100000.b6		    t1.coverage.zymo_log.4.100000.txt
# mbarc_26.9.1000000.b6		    t1.coverage.zymo_log.4.1000000.log
# t1.coverage.gis_20.0.10.log	    t1.coverage.zymo_log.4.1000000.txt
# t1.coverage.gis_20.0.10.txt	    t1.coverage.zymo_log.5.10.log
# t1.coverage.gis_20.0.100.log	    t1.coverage.zymo_log.5.10.txt
# t1.coverage.gis_20.0.100.txt	    t1.coverage.zymo_log.5.100.log
# t1.coverage.gis_20.0.1000.log	    t1.coverage.zymo_log.5.100.txt
# t1.coverage.gis_20.0.1000.txt	    t1.coverage.zymo_log.5.1000.log
# t1.coverage.gis_20.0.10000.log	    t1.coverage.zymo_log.5.1000.txt
# t1.coverage.gis_20.0.10000.txt	    t1.coverage.zymo_log.5.10000.log
# t1.coverage.gis_20.0.100000.log     t1.coverage.zymo_log.5.10000.txt
# t1.coverage.gis_20.0.100000.txt     t1.coverage.zymo_log.5.100000.log
# t1.coverage.gis_20.0.1000000.log    t1.coverage.zymo_log.5.100000.txt
# t1.coverage.gis_20.0.1000000.txt    t1.coverage.zymo_log.5.1000000.log
# t1.coverage.gis_20.1.10.log	    t1.coverage.zymo_log.5.1000000.txt
# t1.coverage.gis_20.1.10.txt	    t1.coverage.zymo_log.6.10.log
# t1.coverage.gis_20.1.100.log	    t1.coverage.zymo_log.6.10.txt
# t1.coverage.gis_20.1.100.txt	    t1.coverage.zymo_log.6.100.log
# t1.coverage.gis_20.1.1000.log	    t1.coverage.zymo_log.6.100.txt
# t1.coverage.gis_20.1.1000.txt	    t1.coverage.zymo_log.6.1000.log
# t1.coverage.gis_20.1.10000.log	    t1.coverage.zymo_log.6.1000.txt
# t1.coverage.gis_20.1.10000.txt	    t1.coverage.zymo_log.6.10000.log
# t1.coverage.gis_20.1.100000.log     t1.coverage.zymo_log.6.10000.txt
# t1.coverage.gis_20.1.100000.txt     t1.coverage.zymo_log.6.100000.log
# t1.coverage.gis_20.1.1000000.log    t1.coverage.zymo_log.6.100000.txt
# t1.coverage.gis_20.1.1000000.txt    t1.coverage.zymo_log.6.1000000.log
# t1.coverage.gis_20.2.10.log	    t1.coverage.zymo_log.6.1000000.txt
# t1.coverage.gis_20.2.10.txt	    t1.coverage.zymo_log.7.10.log
# t1.coverage.gis_20.2.100.log	    t1.coverage.zymo_log.7.10.txt
# t1.coverage.gis_20.2.100.txt	    t1.coverage.zymo_log.7.100.log
# t1.coverage.gis_20.2.1000.log	    t1.coverage.zymo_log.7.100.txt
# t1.coverage.gis_20.2.1000.txt	    t1.coverage.zymo_log.7.1000.log
# t1.coverage.gis_20.2.10000.log	    t1.coverage.zymo_log.7.1000.txt
# t1.coverage.gis_20.2.10000.txt	    t1.coverage.zymo_log.7.10000.log
# t1.coverage.gis_20.2.100000.log     t1.coverage.zymo_log.7.10000.txt
# t1.coverage.gis_20.2.100000.txt     t1.coverage.zymo_log.7.100000.log
# t1.coverage.gis_20.2.1000000.log    t1.coverage.zymo_log.7.100000.txt
# t1.coverage.gis_20.2.1000000.txt    t1.coverage.zymo_log.7.1000000.log
# t1.coverage.gis_20.3.10.log	    t1.coverage.zymo_log.7.1000000.txt
# t1.coverage.gis_20.3.10.txt	    t1.coverage.zymo_log.8.10.log
# t1.coverage.gis_20.3.100.log	    t1.coverage.zymo_log.8.10.txt
# t1.coverage.gis_20.3.100.txt	    t1.coverage.zymo_log.8.100.log
# t1.coverage.gis_20.3.1000.log	    t1.coverage.zymo_log.8.100.txt
# t1.coverage.gis_20.3.1000.txt	    t1.coverage.zymo_log.8.1000.log
# t1.coverage.gis_20.3.10000.log	    t1.coverage.zymo_log.8.1000.txt
# t1.coverage.gis_20.3.10000.txt	    t1.coverage.zymo_log.8.10000.log
# t1.coverage.gis_20.3.100000.log     t1.coverage.zymo_log.8.10000.txt
# t1.coverage.gis_20.3.100000.txt     t1.coverage.zymo_log.8.100000.log
# t1.coverage.gis_20.3.1000000.log    t1.coverage.zymo_log.8.100000.txt
# t1.coverage.gis_20.3.1000000.txt    t1.coverage.zymo_log.8.1000000.log
# t1.coverage.gis_20.4.10.log	    t1.coverage.zymo_log.9.10.log
# t1.coverage.gis_20.4.10.txt	    t1.coverage.zymo_log.9.10.txt
# t1.coverage.gis_20.4.100.log	    t1.coverage.zymo_log.9.100.log
# t1.coverage.gis_20.4.100.txt	    t1.coverage.zymo_log.9.100.txt
# t1.coverage.gis_20.4.1000.log	    t1.coverage.zymo_log.9.1000.log
# t1.coverage.gis_20.4.1000.txt	    t1.coverage.zymo_log.9.1000.txt
# t1.coverage.gis_20.4.10000.log	    t1.coverage.zymo_log.9.10000.log
# t1.coverage.gis_20.4.10000.txt	    t1.coverage.zymo_log.9.10000.txt
# t1.coverage.gis_20.4.100000.log     t1.coverage.zymo_log.9.100000.log
# t1.coverage.gis_20.4.100000.txt     t1.coverage.zymo_log.9.100000.txt
# t1.coverage.gis_20.4.1000000.log    zymo_even.0.10.b6
# t1.coverage.gis_20.4.1000000.txt    zymo_even.0.100.b6
# t1.coverage.gis_20.5.10.log	    zymo_even.0.1000.b6
# t1.coverage.gis_20.5.10.txt	    zymo_even.0.10000.b6
# t1.coverage.gis_20.5.100.log	    zymo_even.0.100000.b6
# t1.coverage.gis_20.5.100.txt	    zymo_even.0.1000000.b6
# t1.coverage.gis_20.5.1000.log	    zymo_even.1.10.b6
# t1.coverage.gis_20.5.1000.txt	    zymo_even.1.100.b6
# t1.coverage.gis_20.5.10000.log	    zymo_even.1.1000.b6
# t1.coverage.gis_20.5.10000.txt	    zymo_even.1.10000.b6
# t1.coverage.gis_20.5.100000.log     zymo_even.1.100000.b6
# t1.coverage.gis_20.5.100000.txt     zymo_even.1.1000000.b6
# t1.coverage.gis_20.5.1000000.log    zymo_even.2.10.b6
# t1.coverage.gis_20.5.1000000.txt    zymo_even.2.100.b6
# t1.coverage.gis_20.6.10.log	    zymo_even.2.1000.b6
# t1.coverage.gis_20.6.10.txt	    zymo_even.2.10000.b6
# t1.coverage.gis_20.6.100.log	    zymo_even.2.100000.b6
# t1.coverage.gis_20.6.100.txt	    zymo_even.2.1000000.b6
# t1.coverage.gis_20.6.1000.log	    zymo_even.3.10.b6
# t1.coverage.gis_20.6.1000.txt	    zymo_even.3.100.b6
# t1.coverage.gis_20.6.10000.log	    zymo_even.3.1000.b6
# t1.coverage.gis_20.6.10000.txt	    zymo_even.3.10000.b6
# t1.coverage.gis_20.6.100000.log     zymo_even.3.100000.b6
# t1.coverage.gis_20.6.100000.txt     zymo_even.3.1000000.b6
# t1.coverage.gis_20.6.1000000.log    zymo_even.4.10.b6
# t1.coverage.gis_20.6.1000000.txt    zymo_even.4.100.b6
# t1.coverage.gis_20.7.10.log	    zymo_even.4.1000.b6
# t1.coverage.gis_20.7.10.txt	    zymo_even.4.10000.b6
# t1.coverage.gis_20.7.100.log	    zymo_even.4.100000.b6
# t1.coverage.gis_20.7.100.txt	    zymo_even.4.1000000.b6
# t1.coverage.gis_20.7.1000.log	    zymo_even.5.10.b6
# t1.coverage.gis_20.7.1000.txt	    zymo_even.5.100.b6
# t1.coverage.gis_20.7.10000.log	    zymo_even.5.1000.b6
# t1.coverage.gis_20.7.10000.txt	    zymo_even.5.10000.b6
# t1.coverage.gis_20.7.100000.log     zymo_even.5.100000.b6
# t1.coverage.gis_20.7.100000.txt     zymo_even.5.1000000.b6
# t1.coverage.gis_20.7.1000000.log    zymo_even.6.10.b6
# t1.coverage.gis_20.7.1000000.txt    zymo_even.6.100.b6
# t1.coverage.gis_20.8.10.log	    zymo_even.6.1000.b6
# t1.coverage.gis_20.8.10.txt	    zymo_even.6.10000.b6
# t1.coverage.gis_20.8.100.log	    zymo_even.6.100000.b6
# t1.coverage.gis_20.8.100.txt	    zymo_even.6.1000000.b6
# t1.coverage.gis_20.8.1000.log	    zymo_even.7.10.b6
# t1.coverage.gis_20.8.1000.txt	    zymo_even.7.100.b6
# t1.coverage.gis_20.8.10000.log	    zymo_even.7.1000.b6
# t1.coverage.gis_20.8.10000.txt	    zymo_even.7.10000.b6
# t1.coverage.gis_20.8.100000.log     zymo_even.7.100000.b6
# t1.coverage.gis_20.8.100000.txt     zymo_even.7.1000000.b6
# t1.coverage.gis_20.8.1000000.log    zymo_even.8.10.b6
# t1.coverage.gis_20.8.1000000.txt    zymo_even.8.100.b6
# t1.coverage.gis_20.9.10.log	    zymo_even.8.1000.b6
# t1.coverage.gis_20.9.10.txt	    zymo_even.8.10000.b6
# t1.coverage.gis_20.9.100.log	    zymo_even.8.100000.b6
# t1.coverage.gis_20.9.100.txt	    zymo_even.8.1000000.b6
# t1.coverage.gis_20.9.1000.log	    zymo_even.9.10.b6
# t1.coverage.gis_20.9.1000.txt	    zymo_even.9.100.b6
# t1.coverage.gis_20.9.10000.log	    zymo_even.9.1000.b6
# t1.coverage.gis_20.9.10000.txt	    zymo_even.9.10000.b6
# t1.coverage.gis_20.9.100000.log     zymo_even.9.100000.b6
# t1.coverage.gis_20.9.100000.txt     zymo_even.9.1000000.b6
# t1.coverage.gis_20.9.1000000.log    zymo_log.0.10.b6
# t1.coverage.gis_20.9.1000000.txt    zymo_log.0.100.b6
# t1.coverage.hmp_even.0.10.log	    zymo_log.0.1000.b6
# t1.coverage.hmp_even.0.10.txt	    zymo_log.0.10000.b6
# t1.coverage.hmp_even.0.100.log	    zymo_log.0.100000.b6
# t1.coverage.hmp_even.0.100.txt	    zymo_log.0.1000000.b6
# t1.coverage.hmp_even.0.1000.log     zymo_log.1.10.b6
# t1.coverage.hmp_even.0.1000.txt     zymo_log.1.100.b6
# t1.coverage.hmp_even.0.10000.log    zymo_log.1.1000.b6
# t1.coverage.hmp_even.0.10000.txt    zymo_log.1.10000.b6
# t1.coverage.hmp_even.0.100000.log   zymo_log.1.100000.b6
# t1.coverage.hmp_even.0.100000.txt   zymo_log.1.1000000.b6
# t1.coverage.hmp_even.0.1000000.log  zymo_log.2.10.b6
# t1.coverage.hmp_even.0.1000000.txt  zymo_log.2.100.b6
# t1.coverage.hmp_even.1.10.log	    zymo_log.2.1000.b6
# t1.coverage.hmp_even.1.10.txt	    zymo_log.2.10000.b6
# t1.coverage.hmp_even.1.100.log	    zymo_log.2.100000.b6
# t1.coverage.hmp_even.1.100.txt	    zymo_log.2.1000000.b6
# t1.coverage.hmp_even.1.1000.log     zymo_log.3.10.b6
# t1.coverage.hmp_even.1.1000.txt     zymo_log.3.100.b6
# t1.coverage.hmp_even.1.10000.log    zymo_log.3.1000.b6
# t1.coverage.hmp_even.1.10000.txt    zymo_log.3.10000.b6
# t1.coverage.hmp_even.1.100000.log   zymo_log.3.100000.b6
# t1.coverage.hmp_even.1.100000.txt   zymo_log.3.1000000.b6
# t1.coverage.hmp_even.1.1000000.log  zymo_log.4.10.b6
# t1.coverage.hmp_even.1.1000000.txt  zymo_log.4.100.b6
# t1.coverage.hmp_even.2.10.log	    zymo_log.4.1000.b6
# t1.coverage.hmp_even.2.10.txt	    zymo_log.4.10000.b6
# t1.coverage.hmp_even.2.100.log	    zymo_log.4.100000.b6
# t1.coverage.hmp_even.2.100.txt	    zymo_log.4.1000000.b6
# t1.coverage.hmp_even.2.1000.log     zymo_log.5.10.b6
# t1.coverage.hmp_even.2.1000.txt     zymo_log.5.100.b6
# t1.coverage.hmp_even.2.10000.log    zymo_log.5.1000.b6
# t1.coverage.hmp_even.2.10000.txt    zymo_log.5.10000.b6
# t1.coverage.hmp_even.2.100000.log   zymo_log.5.100000.b6
# t1.coverage.hmp_even.2.100000.txt   zymo_log.5.1000000.b6
# t1.coverage.hmp_even.2.1000000.log  zymo_log.6.10.b6
# t1.coverage.hmp_even.2.1000000.txt  zymo_log.6.100.b6
# t1.coverage.hmp_even.3.10.log	    zymo_log.6.1000.b6
# t1.coverage.hmp_even.3.10.txt	    zymo_log.6.10000.b6
# t1.coverage.hmp_even.3.100.log	    zymo_log.6.100000.b6
# t1.coverage.hmp_even.3.100.txt	    zymo_log.6.1000000.b6
# t1.coverage.hmp_even.3.1000.log     zymo_log.7.10.b6
# t1.coverage.hmp_even.3.1000.txt     zymo_log.7.100.b6
# t1.coverage.hmp_even.3.10000.log    zymo_log.7.1000.b6
# t1.coverage.hmp_even.3.10000.txt    zymo_log.7.10000.b6
# t1.coverage.hmp_even.3.100000.log   zymo_log.7.100000.b6
# t1.coverage.hmp_even.3.100000.txt   zymo_log.7.1000000.b6
# t1.coverage.hmp_even.3.1000000.log  zymo_log.8.10.b6
# t1.coverage.hmp_even.3.1000000.txt  zymo_log.8.100.b6
# t1.coverage.hmp_even.4.10.log	    zymo_log.8.1000.b6
# t1.coverage.hmp_even.4.10.txt	    zymo_log.8.10000.b6
# t1.coverage.hmp_even.4.100.log	    zymo_log.8.100000.b6
# t1.coverage.hmp_even.4.100.txt	    zymo_log.8.1000000.b6
# t1.coverage.hmp_even.4.1000.log     zymo_log.9.10.b6
# t1.coverage.hmp_even.4.1000.txt     zymo_log.9.100.b6
# t1.coverage.hmp_even.4.10000.log    zymo_log.9.1000.b6
# t1.coverage.hmp_even.4.10000.txt    zymo_log.9.10000.b6
# t1.coverage.hmp_even.4.100000.log   zymo_log.9.100000.b6
# t1.coverage.hmp_even.4.100000.txt   zymo_log.9.1000000.b6
# t1.coverage.hmp_even.4.1000000.log

# %%
ra_mask = df_capitalist_species["relative_abundace"] > .005

basepath_sim = "/mnt/btrfs/data/type_1/simulation_metagenome/"
db_features = "/mnt/nvidia/pkr/code/type_1/data/db_features.csv"

df_c_ra = df_capitalist_species[ra_mask]

strain_probas = []

for dataset in ["zymo", "mbarc", "hmp", "gis"]:
    
    X_type_1 = df_type_1_features.loc[:, df_type_1_features.columns.difference(["shannon_entropy"])]
                                                 
    X_type_1 = X_type_1.replace([np.inf, -np.inf], np.nan)
    X_type_1 = X_type_1.dropna()
    
    mask_dataset = np.array([_.startswith(dataset) for _ in X_type_1["dataset"]])

    y = X_type_1["truth"]
    X_type_1 = X_type_1.loc[:, X_type_1.columns.difference(["assembly_accession", "dataset", "truth"])]
    
    X_type_1_train = X_type_1.loc[~mask_dataset, :]
    X_type_1_test =  X_type_1.loc[mask_dataset, :]
    y_train = y.loc[~mask_dataset]
    y_test = y.loc[mask_dataset]
    
    clf = RandomForestClassifier(random_state=42)

    clf.fit(X_type_1_train, y_train)
    
    text_files = glob(f"{basepath_sim}/*{dataset}*.txt", recursive=True)
    dfs = []
    for file in text_files:
        dfs.append(pd.read_csv(file, index_col = 0))
    df_orig_strain = pd.concat(dfs)
    
    df_orig_strain = df_orig_strain.replace([np.inf, -np.inf], np.nan)
    df_orig_strain = df_orig_strain.dropna()

    df_strain = df_orig_strain.loc[:, df_orig_strain.columns.difference(["assembly_accession", "shannon_entropy"])]
    

    probas = clf.predict_proba(df_strain)

    df_strain["proba"] = probas[:,1]
    df_strain["dataset"] = dataset
    df_strain["assembly_accession"] = df_orig_strain["assembly_accession"]
    df_strain["shannon_entropy"] = df_orig_strain["shannon_entropy"]
    
    strain_probas.append(df_strain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-05a61594af53> in <module>
#      33     for file in text_files:
#      34         dfs.append(pd.read_csv(file, index_col = 0))
# ---> 35     df_orig_strain = pd.concat(dfs)
#      36
#      37     df_orig_strain = df_orig_strain.replace([np.inf, -np.inf], np.nan)
#
# ~/.conda/envs/type_1/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     269     ValueError: Indexes have overlapping values: ['a']
#     270     """
# --> 271     op = _Concatenator(
#     272         objs,
#     273         axis=axis,
#
# ~/.conda/envs/type_1/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     327
#     328         if len(objs) == 0:
# --> 329             raise ValueError("No objects to concatenate")
#     330
#     331         if keys is None:
#
# ValueError: No objects to concatenate

# %%
df_strains = pd.concat(strain_probas)

# %%
df_strains.sort_values("hits", inplace=True)
g = sns.FacetGrid(df_strains, col="assembly_accession", col_wrap=2)
g.map(plt.scatter, "hits", "proba")
plt.show()

# %%
df_strains[df_strains.percent_coverage > 1.0].percent_coverage.max()

# %%
df_strains["percent_coverage"].hist()

# %%
df_strains["percent_coverage"].max()

# %%
df_strains.sort_values("percent_coverage", inplace=True)
g = sns.FacetGrid(df_strains, col="assembly_accession", col_wrap=2, height=4)
g.map(sns.lineplot, "percent_coverage", "proba")
plt.show()
