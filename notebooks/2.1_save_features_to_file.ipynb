# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import seaborn as sns

from scipy.stats import pearsonr

sns.set_style("darkgrid")
np.random.seed(930525)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 200)

warnings.simplefilter('once')

# %matplotlib inline
# %load_ext watermark
# %watermark --iversions
# Out:
# seaborn 0.10.1
# pandas  1.1.4
# numpy   1.18.4

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import plot_roc_curve
from sklearn.ensemble import RandomForestClassifier
import shap

import pandas as pd
import requests

from io import StringIO
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
from collections import defaultdict

url = requests.get('https://docs.google.com/spreadsheets/d/1KO_wGiEagJ8PMO2BzSDI1IXHYO4RHZMMSWXlT48peiQ/export?format=csv')
csv_raw = StringIO(url.text)
df_truth = pd.read_csv(csv_raw)

inf_tax_file = "/mnt/btrfs/data/gtdb_95/gtdb_genomes_reps_r95/r95.gtdb.tax"

# %% [markdown]
# # Building the true species dataset

# %%
df_tax = pd.read_csv(inf_tax_file, names=["assembly_accession", "tax"], sep="\t")

df_tax["species"] = [";".join(_.split(";")[:7]) for _ in df_tax.tax]
df_tax["genus"] = [";".join(_.split(";")[:6]) for _ in df_tax.tax]
df_tax["family"] = [";".join(_.split(";")[:5]) for _ in df_tax.tax]

# %%
dd = dict()
for group, df in df_truth.groupby('dataset'):
    dd[group] = set(df["database_accession"].values)
    if np.nan in dd[group]:
        dd[group].remove(np.nan)

# %%
from glob import glob
import os

files = glob("/mnt/btrfs/data/type_1/species_mc/b6_split_by_sample/*.extra.csv")

dfs = []
for file in files:
    name = '_'.join(os.path.basename(file).split('.')[:-3])
    if name == "test_sort":
        continue
    df = pd.read_csv(file, index_col = 0)
    df['dataset'] = name
    dfs.append(df)
df_type_1_features = pd.concat(dfs)
# Out:
# Columns (84,88,97,106) have mixed types.Specify dtype option on import or set low_memory=False.
# Columns (47,49,55,56,57,58,70,83,95,96,100,103,104,108,109) have mixed types.Specify dtype option on import or set low_memory=False.
# Columns (70,83,95,96,100,103,104,108,109) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
rows = []
for t in df_type_1_features.itertuples():
    if t.assembly_accession in dd[t.dataset]:
        rows.append(True)
    else:
        rows.append(False)
df_type_1_features["truth"] = rows

# %%
df_type_1_features['truth'].sum()
# Out:
# 122

# %%
# mask_eubacterium = [_ in eubacteriums for _ in df_type_1_features['assembly_accession']]

# %%
df_type_1_features.groupby('truth').mean()
# Out:
#                hits  percent_coverage  mean_coverage  sd_coverage  \
# truth
# False  3.239319e+03          0.000875       0.092289     2.531930
# True   1.880543e+06          0.703774      85.043975    99.475321
#
#        percent_padded_coverage  mean_padded_coverage  sd_padded_coverage  \
# truth
# False                 0.001534              0.154517            3.746302
# True                  0.751646            113.741787          118.544562
#
#        percent_binned_coverage  mean_binned_coverage  sd_binned_coverage  ...  \
# truth                                                                     ...
# False                 0.002177              0.323931            6.280481  ...
# True                  0.786987            188.054088          191.574473  ...
#
#        gf_mean_scaffold_length  gf_n50_contigs  gf_n50_scaffolds  \
# truth
# False             8.061090e+05    1.094139e+06      1.250438e+06
# True              2.212078e+06    2.763453e+06      2.922896e+06
#
#        gf_protein_count  gf_scaffold_count  gf_ssu_count  gf_total_gap_length  \
# truth
# False       3818.894454          76.263736      2.158391          9811.494846
# True        3310.090164          13.737705      4.311475          5892.532787
#
#        gf_trna_aa_count  gf_trna_count  gf_trna_selenocysteine_count
# truth
# False         19.337915      51.752234                      0.161085
# True          19.581967      59.286885                      0.139344
#
# [2 rows x 50 columns]

# %%
df_type_1_features.groupby('dataset').mean()
# Out:
#                        hits  percent_coverage  mean_coverage  sd_coverage  \
# dataset
# dual_index        99.186609          0.001536       0.004886     0.052115
# gis_20         19253.052920          0.002234       0.586960    11.445821
# hmp_even        1165.422709          0.002070       0.026119     0.671371
# hmp_staggered    652.053147          0.001033       0.012736     0.459527
# mbarc_26        6937.558789          0.002394       0.408469     1.163047
# zymo_even        559.568718          0.001024       0.026347     0.308280
# zymo_log        7514.998980          0.000722       0.234523     3.888986
#
#                percent_padded_coverage  mean_padded_coverage  \
# dataset
# dual_index                    0.001993              0.006192
# gis_20                        0.002878              0.893255
# hmp_even                      0.003497              0.073089
# hmp_staggered                 0.002010              0.041127
# mbarc_26                      0.002622              0.382670
# zymo_even                     0.001395              0.032079
# zymo_log                      0.001169              0.478779
#
#                sd_padded_coverage  percent_binned_coverage  \
# dataset
# dual_index               0.070818                 0.002589
# gis_20                  16.024400                 0.003691
# hmp_even                 1.383517                 0.004409
# hmp_staggered            1.011300                 0.002785
# mbarc_26                 1.124678                 0.003124
# zymo_even                0.377924                 0.001870
# zymo_log                 6.214730                 0.001690
#
#                mean_binned_coverage  sd_binned_coverage  ...  gf_n50_contigs  \
# dataset                                                  ...
# dual_index                 0.009919            0.106076  ...    1.129564e+06
# gis_20                     1.925302           29.261207  ...    1.127082e+06
# hmp_even                   0.116542            1.978580  ...    1.036182e+06
# hmp_staggered              0.065205            1.435355  ...    1.057824e+06
# mbarc_26                   0.693755            1.796629  ...    1.135078e+06
# zymo_even                  0.055957            0.594392  ...    1.106914e+06
# zymo_log                   0.751497            8.552841  ...    1.110680e+06
#
#                gf_n50_scaffolds  gf_protein_count  gf_scaffold_count  \
# dataset
# dual_index         1.294797e+06       3807.313737          69.550468
# gis_20             1.277582e+06       3916.328516          77.123373
# hmp_even           1.183016e+06       3798.242926          83.113132
# hmp_staggered      1.207405e+06       3821.154354          81.732126
# mbarc_26           1.306175e+06       3898.536280          79.262254
# zymo_even          1.267416e+06       3743.073659          69.400121
# zymo_log           1.269649e+06       3750.678970          69.803925
#
#                gf_ssu_count  gf_total_gap_length  gf_trna_aa_count  \
# dataset
# dual_index         2.265561         10889.223855         19.431568
# gis_20             2.143669          6616.306147         19.360873
# hmp_even           2.005308          9276.677129         19.196538
# hmp_staggered      2.043972          9402.177458         19.252472
# mbarc_26           2.324745         12627.015178         19.385977
# zymo_even          2.226796         10587.274386         19.409942
# zymo_log           2.229324         10524.154483         19.405714
#
#                gf_trna_count  gf_trna_selenocysteine_count     truth
# dataset
# dual_index         52.481377                      0.155392  0.001193
# gis_20             51.803942                      0.162744  0.001010
# hmp_even           50.275467                      0.163720  0.000969
# hmp_staggered      50.632297                      0.167380  0.000998
# mbarc_26           54.081964                      0.177699  0.001925
# zymo_even          52.195089                      0.148348  0.000485
# zymo_log           52.059537                      0.152263  0.000480
#
# [7 rows x 51 columns]

# %%
list(df_type_1_features.columns)
# Out:
# ['assembly_accession',
#  'hits',
#  'percent_coverage',
#  'mean_coverage',
#  'sd_coverage',
#  'percent_padded_coverage',
#  'mean_padded_coverage',
#  'sd_padded_coverage',
#  'percent_binned_coverage',
#  'mean_binned_coverage',
#  'sd_binned_coverage',
#  'expected_percent_coverage',
#  'shannon_entropy',
#  'percent_max_uncovered_region',
#  'largest_pileup',
#  'largest_padded_pileup',
#  'largest_binned_pileup',
#  'gc_content',
#  'total_genome_length',
#  'ungapped_genome_length',
#  'num_n_groups',
#  'consecutive_ns',
#  'gf_accession',
#  'gf_ambiguous_bases',
#  'gf_checkm_completeness',
#  'gf_checkm_contamination',
#  'gf_checkm_marker_count',
#  'gf_checkm_marker_lineage',
#  'gf_checkm_marker_set_count',
#  'gf_checkm_strain_heterogeneity',
#  'gf_coding_bases',
#  'gf_coding_density',
#  'gf_contig_count',
#  'gf_gc_count',
#  'gf_gc_percentage',
#  'gf_genome_size',
#  'gf_gtdb_genome_representative',
#  'gf_gtdb_representative',
#  'gf_gtdb_taxonomy',
#  'gf_gtdb_type_designation',
#  'gf_gtdb_type_designation_sources',
#  'gf_gtdb_type_species_of_genus',
#  'gf_l50_contigs',
#  'gf_l50_scaffolds',
#  'gf_longest_contig',
#  'gf_longest_scaffold',
#  'gf_lsu_23s_contig_len',
#  'gf_lsu_23s_count',
#  'gf_lsu_23s_length',
#  'gf_lsu_23s_query_id',
#  'gf_lsu_5s_contig_len',
#  'gf_lsu_5s_count',
#  'gf_lsu_5s_length',
#  'gf_lsu_5s_query_id',
#  'gf_lsu_silva_23s_blast_align_len',
#  'gf_lsu_silva_23s_blast_bitscore',
#  'gf_lsu_silva_23s_blast_evalue',
#  'gf_lsu_silva_23s_blast_perc_identity',
#  'gf_lsu_silva_23s_blast_subject_id',
#  'gf_lsu_silva_23s_taxonomy',
#  'gf_mean_contig_length',
#  'gf_mean_scaffold_length',
#  'gf_mimag_high_quality',
#  'gf_mimag_low_quality',
#  'gf_mimag_medium_quality',
#  'gf_n50_contigs',
#  'gf_n50_scaffolds',
#  'gf_ncbi_assembly_level',
#  'gf_ncbi_assembly_name',
#  'gf_ncbi_assembly_type',
#  'gf_ncbi_bioproject',
#  'gf_ncbi_biosample',
#  'gf_ncbi_contig_count',
#  'gf_ncbi_contig_n50',
#  'gf_ncbi_country',
#  'gf_ncbi_date',
#  'gf_ncbi_genbank_assembly_accession',
#  'gf_ncbi_genome_category',
#  'gf_ncbi_genome_representation',
#  'gf_ncbi_isolate',
#  'gf_ncbi_isolation_source',
#  'gf_ncbi_lat_lon',
#  'gf_ncbi_molecule_count',
#  'gf_ncbi_ncrna_count',
#  'gf_ncbi_organism_name',
#  'gf_ncbi_protein_count',
#  'gf_ncbi_refseq_category',
#  'gf_ncbi_rrna_count',
#  'gf_ncbi_scaffold_count',
#  'gf_ncbi_scaffold_l50',
#  'gf_ncbi_scaffold_n50',
#  'gf_ncbi_scaffold_n75',
#  'gf_ncbi_scaffold_n90',
#  'gf_ncbi_seq_rel_date',
#  'gf_ncbi_spanned_gaps',
#  'gf_ncbi_species_taxid',
#  'gf_ncbi_ssu_count',
#  'gf_ncbi_strain_identifiers',
#  'gf_ncbi_submitter',
#  'gf_ncbi_taxid',
#  'gf_ncbi_taxonomy',
#  'gf_ncbi_taxonomy_unfiltered',
#  'gf_ncbi_total_gap_length',
#  'gf_ncbi_total_length',
#  'gf_ncbi_translation_table',
#  'gf_ncbi_trna_count',
#  'gf_ncbi_type_material_designation',
#  'gf_ncbi_ungapped_length',
#  'gf_ncbi_unspanned_gaps',
#  'gf_ncbi_wgs_master',
#  'gf_protein_count',
#  'gf_scaffold_count',
#  'gf_ssu_contig_len',
#  'gf_ssu_count',
#  'gf_ssu_gg_blast_align_len',
#  'gf_ssu_gg_blast_bitscore',
#  'gf_ssu_gg_blast_evalue',
#  'gf_ssu_gg_blast_perc_identity',
#  'gf_ssu_gg_blast_subject_id',
#  'gf_ssu_gg_taxonomy',
#  'gf_ssu_length',
#  'gf_ssu_query_id',
#  'gf_ssu_silva_blast_align_len',
#  'gf_ssu_silva_blast_bitscore',
#  'gf_ssu_silva_blast_evalue',
#  'gf_ssu_silva_blast_perc_identity',
#  'gf_ssu_silva_blast_subject_id',
#  'gf_ssu_silva_taxonomy',
#  'gf_total_gap_length',
#  'gf_trna_aa_count',
#  'gf_trna_count',
#  'gf_trna_selenocysteine_count',
#  'dataset',
#  'truth']

# %%
df_type_1_features.reset_index(drop=True).to_csv("../notebooks/strains.dataset.csv")
