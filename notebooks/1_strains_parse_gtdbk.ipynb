# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import seaborn as sns

from scipy.stats import pearsonr

sns.set_style("darkgrid")
np.random.seed(930525)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 200)

warnings.simplefilter('once')

# %matplotlib inline
# %load_ext watermark
# %watermark --iversions
# Out:
# seaborn 0.10.1
# numpy   1.18.4
# pandas  1.0.4

# %%
import requests

from io import StringIO

# %%
from collections import defaultdict

url = requests.get('https://docs.google.com/spreadsheets/d/1OYgLNTSd1BvFyGk9ps6xEaEk1KGoPx5VIgb_awHUXR4/export?format=csv')
csv_raw = StringIO(url.text)
df_truth = pd.read_csv(csv_raw)

inf_tax_file = "/mnt/btrfs/data/gtdb_95/gtdb_genomes_reps_r95/r95.gtdb.tax"

# %%
inf_archaea_summary = "/mnt/btrfs/data/type_1/gtdbtk_strains_lin/classify/gtdbtk.ar122.summary.tsv"

inf_bacteria_summary = "/mnt/btrfs/data/type_1/gtdbtk_strains_lin/classify/gtdbtk.bac120.summary.tsv"

# %%
df_archaea_summary = pd.read_csv(inf_archaea_summary, sep="\t")
df_bacteria_summary = pd.read_csv(inf_bacteria_summary, sep="\t")

# %%
df_summary = pd.concat([df_archaea_summary, df_bacteria_summary])

# %%
df_summary.head()
# Out:
#                     user_genome  \
# 0   GCA_000182965.lin.noplasmid
# 1  scerevisiae_pb.lin.noplasmid
# 0   GCA_000006885.lin.noplasmid
# 1   GCA_000006785.lin.noplasmid
# 2   GCA_000007265.lin.noplasmid
#
#                                       classification fastani_reference  \
# 0  d__Archaea;p__Thermoproteota;c__Nitrososphaeri...               NaN
# 1  d__Archaea;p__Asgardarchaeota;c__Heimdallarcha...               NaN
# 0  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...   GCF_001457635.1
# 1  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...   GCF_002055535.1
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...   GCF_000186445.1
#
#    fastani_reference_radius  \
# 0                       NaN
# 1                       NaN
# 0                      95.0
# 1                      95.0
# 2                      95.0
#
#                                     fastani_taxonomy  fastani_ani  fastani_af  \
# 0                                                NaN          NaN         NaN
# 1                                                NaN          NaN         NaN
# 0  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        98.67        0.91
# 1  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        99.78        0.96
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...        98.41        0.85
#
#   closest_placement_reference  closest_placement_radius  \
# 0             GCA_003661605.1                      95.0
# 1                         NaN                       NaN
# 0             GCF_001457635.1                      95.0
# 1             GCF_002055535.1                      95.0
# 2             GCF_000186445.1                      95.0
#
#                           closest_placement_taxonomy  ...  \
# 0  d__Archaea;p__Thermoproteota;c__Nitrososphaeri...  ...
# 1                                                NaN  ...
# 0  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...  ...
# 1  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...  ...
# 2  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...  ...
#
#    closest_placement_af                                   pplacer_taxonomy  \
# 0                  0.00  d__Archaea;p__Thermoproteota;c__Nitrososphaeri...
# 1                   NaN  d__Archaea;p__Asgardarchaeota;c__Heimdallarcha...
# 0                  0.91  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 1                  0.96  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2                  0.85  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
#
#                                classification_method  \
# 0  taxonomic classification defined by topology a...
# 1             taxonomic novelty determined using RED
# 0  taxonomic classification defined by topology a...
# 1  taxonomic classification defined by topology a...
# 2  taxonomic classification defined by topology a...
#
#                                                 note  \
# 0                                                NaN
# 1                                                NaN
# 0  topological placement and ANI have congruent s...
# 1  topological placement and ANI have congruent s...
# 2  topological placement and ANI have congruent s...
#
#   other_related_references(genome_id,species_name,radius,ANI,AF) aa_percent  \
# 0                                                NaN                  52.69
# 1                                                NaN                  37.65
# 0  GCF_002087075.1, s__Streptococcus pseudopneumo...                  98.02
# 1  GCF_000188315.1, s__Streptococcus dysgalactiae...                  97.94
# 2  GCF_000188035.1, s__Streptococcus pseudoporcin...                  97.88
#
#    translation_table  red_value  \
# 0                 11   0.453623
# 1                 11   0.372364
# 0                 11        NaN
# 1                 11        NaN
# 2                 11        NaN
#
#                                             warnings  mapping_genome
# 0  Genome has more than 10.7% of markers with mul...   GCA_000182965
# 1  Genome has more than 27.0% of markers with mul...  scerevisiae_pb
# 0                                                NaN   GCA_000006885
# 1                                                NaN   GCA_000006785
# 2                                                NaN   GCA_000007265
#
# [5 rows x 21 columns]

# %%
df_summary['mapping_genome'] = ['.'.join(_.split('.')[:-2]).replace("GCA", "GCF") for _ in df_summary['user_genome']]

# %%
df_joined['mapping_genome']
# Out:
# 0                                                   NaN
# 1                                         GCF_000016305
# 2                                         GCF_001077675
# 3                                         GCF_000007645
# 4                                         GCF_000174395
# 5                                         GCF_000743055
# 6                                         GCF_005221305
# 7                                         GCF_000023285
# 8                                         GCF_000010005
# 9                                         GCF_000196555
# 10                                        GCF_000237805
# 11                                        GCF_000010185
# 12                                        GCF_000025565
# 13                                        GCF_000154325
# 14                                        GCF_000010425
# 15                                        GCF_000164675
# 16                                        GCF_000153625
# 17                                        GCF_000377685
# 18                                        GCF_000349975
# 19                                        GCF_000191785
# 20                                         bsubtilis_pb
# 21                                      cneoformans_ont
# 22                                         efaecalis_pb
# 23                                             ecoli_pb
# 24                                 lfermentum_ontlumina
# 25                                    lmonocytogenes_pb
# 26                                       paeruginosa_pb
# 27                                       scerevisiae_pb
# 28                                         senterica_pb
# 29                                           saureus_pb
# 30                                         bsubtilis_pb
# 31                                      cneoformans_ont
# 32                                         efaecalis_pb
# 33                                             ecoli_pb
# 34                                 lfermentum_ontlumina
# 35                                    lmonocytogenes_pb
# 36                                       paeruginosa_pb
# 37                                       scerevisiae_pb
# 38                                         senterica_pb
# 39                                           saureus_pb
# 40                                        GCF_001077675
# 41                                        GCF_000154225
# 42                                        GCF_000008005
# 43                                        GCF_000012825
# 44                                        GCF_000182965
# 45                                        GCF_000016965
# 46                                        GCF_008329785
# 47                                        GCF_000172575
# 48                                        GCF_001542625
# 49                                        GCF_000307795
# 50                                        GCF_000014425
# 51                                        GCF_000196035
# 52                                        GCF_000016525
# 53                  Neisseria_meningitidis_ATCC_BAA_335
# 54                                        GCF_000008345
# 55                    Pseudomonas_aeruginosa_ATCC_47085
# 56                                        GCF_003324715
# 57     Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718
# 58                                        GCF_009873455
# 59                                        GCF_000007265
# 60                                        GCF_000007465
# 61                                        GCF_000006885
# 62                                        GCF_001077675
# 63                                        GCF_000154225
# 64                                        GCF_000008005
# 65                                        GCF_000012825
# 66                                        GCF_000182965
# 67                                        GCF_000016965
# 68                                        GCF_008329785
# 69                                        GCF_000172575
# 70                                        GCF_001542625
# 71                                        GCF_000307795
# 72                                        GCF_000014425
# 73                                        GCF_000196035
# 74                                        GCF_000016525
# 75                  Neisseria_meningitidis_ATCC_BAA_335
# 76                                        GCF_000008345
# 77                    Pseudomonas_aeruginosa_ATCC_47085
# 78                                        GCF_003324715
# 79     Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718
# 80                                        GCF_009873455
# 81                                        GCF_000007265
# 82                                        GCF_000007465
# 83                                        GCF_000006885
# 84                                        GCF_000265425
# 85                                        GCF_000011325
# 86                                        GCF_000092985
# 87                                        GCF_000143845
# 88                                        GCF_000092825
# 89                                        GCF_000325705
# 90                                        GCF_000092125
# 91                                        GCF_000013285
# 92                                        GCF_000015865
# 93                                        GCF_000255115
# 94                                        GCF_000231385
# 95                                        GCF_000233715
# 96                                        GCF_000006785
# 97                                        GCF_000227705
# 98                                        GCF_000005845
# 99                                        GCF_000242255
# 100                                       GCF_000023785
# 101                                       GCF_000327065
# 102                                       GCF_000252995
# 103                                       GCF_000018625
# 104                                       GCF_000143985
# 105                                       GCF_000235405
# 106                                       GCF_000025905
# 107                                       GCF_000328525
# 108                                       GCF_000230715
# 109                                       GCF_000328685
# 110                                       GCF_001077675
# 111                                       GCF_000154225
# 112                                       GCF_000008005
# 113                                       GCF_000012825
# 114                                       GCF_000016965
# 115                                       GCF_008329785
# 116                                       GCF_000172575
# 117                                       GCF_001542625
# 118                                       GCF_000307795
# 119                                       GCF_000014425
# 120                                       GCF_000196035
# 121                 Neisseria_meningitidis_ATCC_BAA_335
# 122                                       GCF_000008345
# 123                   Pseudomonas_aeruginosa_ATCC_47085
# 124                                       GCF_003324715
# 125    Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718
# 126                                       GCF_009873455
# 127                                       GCF_000007265
# 128                                       GCF_000007465
# 129                                       GCF_000006885
# Name: mapping_genome, dtype: object

# %%
df_summary['mapping_genome']
# Out:
# 0                                        GCF_000182965
# 1                                       scerevisiae_pb
# 0                                        GCF_000006885
# 1                                        GCF_000006785
# 2                                        GCF_000007265
# 3                                        GCF_000007465
# 4                                        GCF_000174395
# 5                                         efaecalis_pb
# 6                                        GCF_000172575
# 7                                        GCF_000010005
# 8                                 lfermentum_ontlumina
# 9                                    lmonocytogenes_pb
# 10                                       GCF_000196035
# 11                                       GCF_009873455
# 12                                       GCF_000007645
# 13    Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718
# 14                                          saureus_pb
# 15                                        bsubtilis_pb
# 16                                       GCF_000008005
# 17                                       GCF_000153625
# 18                                       GCF_000016965
# 19                                       GCF_000191785
# 20                                       GCF_000008345
# 21                                       GCF_008329785
# 22                   Pseudomonas_aeruginosa_ATCC_47085
# 23                                      paeruginosa_pb
# 24                                       GCF_001077675
# 25                                            ecoli_pb
# 26                                       GCF_000005845
# 27                                       GCF_000743055
# 28                                        senterica_pb
# 29                                       GCF_000016305
# 30                 Neisseria_meningitidis_ATCC_BAA_335
# 31                                       GCF_003324715
# 32                                       GCF_000377685
# 33                                       GCF_000307795
# 34                                       GCF_000349975
# Name: mapping_genome, dtype: object

# %%
df_joined = pd.merge(df_truth, df_summary, how="left", on="mapping_genome")

# %%
db_accession = []
for accession, reference in zip(df_joined['database_accession'], df_joined['fastani_reference']):
    if type(accession) == type(" "):
        db_accession.append(accession)
    elif type(reference) == type(" "):
        db_accession.append(reference)
    else:
        db_accession.append("")

# %%
df_joined['database_accession'] = db_accession

# %%
df_joined.to_csv("/mnt/btrfs/data/type_1/strains.truth.csv", index=False)
df_joined.to_csv("./strains.truth.csv", index=False)

# %%
df_joined['mapping_genome']
# Out:
# 0                                                   NaN
# 1                                         GCF_000016305
# 2                                         GCF_001077675
# 3                                         GCF_000007645
# 4                                         GCF_000174395
# 5                                         GCF_000743055
# 6                                         GCF_005221305
# 7                                         GCF_000023285
# 8                                         GCF_000010005
# 9                                         GCF_000196555
# 10                                        GCF_000237805
# 11                                        GCF_000010185
# 12                                        GCF_000025565
# 13                                        GCF_000154325
# 14                                        GCF_000010425
# 15                                        GCF_000164675
# 16                                        GCF_000153625
# 17                                        GCF_000377685
# 18                                        GCF_000349975
# 19                                        GCF_000191785
# 20                                         bsubtilis_pb
# 21                                      cneoformans_ont
# 22                                         efaecalis_pb
# 23                                             ecoli_pb
# 24                                 lfermentum_ontlumina
# 25                                    lmonocytogenes_pb
# 26                                       paeruginosa_pb
# 27                                       scerevisiae_pb
# 28                                         senterica_pb
# 29                                           saureus_pb
# 30                                         bsubtilis_pb
# 31                                      cneoformans_ont
# 32                                         efaecalis_pb
# 33                                             ecoli_pb
# 34                                 lfermentum_ontlumina
# 35                                    lmonocytogenes_pb
# 36                                       paeruginosa_pb
# 37                                       scerevisiae_pb
# 38                                         senterica_pb
# 39                                           saureus_pb
# 40                                        GCF_001077675
# 41                                        GCF_000154225
# 42                                        GCF_000008005
# 43                                        GCF_000012825
# 44                                        GCF_000182965
# 45                                        GCF_000016965
# 46                                        GCF_008329785
# 47                                        GCF_000172575
# 48                                        GCF_001542625
# 49                                        GCF_000307795
# 50                                        GCF_000014425
# 51                                        GCF_000196035
# 52                                        GCF_000016525
# 53                  Neisseria_meningitidis_ATCC_BAA_335
# 54                                        GCF_000008345
# 55                    Pseudomonas_aeruginosa_ATCC_47085
# 56                                        GCF_003324715
# 57     Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718
# 58                                        GCF_009873455
# 59                                        GCF_000007265
# 60                                        GCF_000007465
# 61                                        GCF_000006885
# 62                                        GCF_001077675
# 63                                        GCF_000154225
# 64                                        GCF_000008005
# 65                                        GCF_000012825
# 66                                        GCF_000182965
# 67                                        GCF_000016965
# 68                                        GCF_008329785
# 69                                        GCF_000172575
# 70                                        GCF_001542625
# 71                                        GCF_000307795
# 72                                        GCF_000014425
# 73                                        GCF_000196035
# 74                                        GCF_000016525
# 75                  Neisseria_meningitidis_ATCC_BAA_335
# 76                                        GCF_000008345
# 77                    Pseudomonas_aeruginosa_ATCC_47085
# 78                                        GCF_003324715
# 79     Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718
# 80                                        GCF_009873455
# 81                                        GCF_000007265
# 82                                        GCF_000007465
# 83                                        GCF_000006885
# 84                                        GCF_000265425
# 85                                        GCF_000011325
# 86                                        GCF_000092985
# 87                                        GCF_000143845
# 88                                        GCF_000092825
# 89                                        GCF_000325705
# 90                                        GCF_000092125
# 91                                        GCF_000013285
# 92                                        GCF_000015865
# 93                                        GCF_000255115
# 94                                        GCF_000231385
# 95                                        GCF_000233715
# 96                                        GCF_000006785
# 97                                        GCF_000227705
# 98                                        GCF_000005845
# 99                                        GCF_000242255
# 100                                       GCF_000023785
# 101                                       GCF_000327065
# 102                                       GCF_000252995
# 103                                       GCF_000018625
# 104                                       GCF_000143985
# 105                                       GCF_000235405
# 106                                       GCF_000025905
# 107                                       GCF_000328525
# 108                                       GCF_000230715
# 109                                       GCF_000328685
# 110                                       GCF_001077675
# 111                                       GCF_000154225
# 112                                       GCF_000008005
# 113                                       GCF_000012825
# 114                                       GCF_000016965
# 115                                       GCF_008329785
# 116                                       GCF_000172575
# 117                                       GCF_001542625
# 118                                       GCF_000307795
# 119                                       GCF_000014425
# 120                                       GCF_000196035
# 121                 Neisseria_meningitidis_ATCC_BAA_335
# 122                                       GCF_000008345
# 123                   Pseudomonas_aeruginosa_ATCC_47085
# 124                                       GCF_003324715
# 125    Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718
# 126                                       GCF_009873455
# 127                                       GCF_000007265
# 128                                       GCF_000007465
# 129                                       GCF_000006885
# Name: mapping_genome, dtype: object

# %%
# Out:
# ['',
#  'GCF_000742135',
#  'GCF_002811175',
#  'GCF_006742205',
#  'GCF_001544255',
#  'GCF_000006945',
#  'GCF_005221305',
#  'GCF_000023285',
#  'GCF_000016825',
#  'GCF_000196555',
#  'GCF_000237805',
#  'GCF_000010185',
#  'GCF_000025565',
#  'GCF_000154325',
#  'GCF_000010425',
#  'GCF_000164675',
#  'GCF_001457555',
#  'GCF_900637655',
#  'GCF_000155475',
#  'GCF_001042675',
#  'GCA_001274925',
#  '',
#  'GCF_000392875',
#  'GCF_002950215',
#  'GCF_000159215',
#  'GCF_000307025',
#  'GCF_001457615',
#  '',
#  'GCF_000006945',
#  'GCF_001027105',
#  'GCA_001274925',
#  '',
#  'GCF_000392875',
#  'GCF_002950215',
#  'GCF_000159215',
#  'GCF_000307025',
#  'GCF_001457615',
#  '',
#  'GCF_000006945',
#  'GCF_001027105',
#  'GCF_002811175',
#  'GCF_000154225',
#  'GCF_001883995',
#  'GCF_000012825',
#  '',
#  'GCF_002006445',
#  'GCF_000008565',
#  'GCF_000392875',
#  'GCF_001542625',
#  'GCF_900478295',
#  'GCF_000014425',
#  'GCF_900187225',
#  'GCF_000016525',
#  'GCF_900638555',
#  'GCF_003030305',
#  'GCF_001457615',
#  'GCF_000012905',
#  'GCF_001027105',
#  'GCF_006742205',
#  'GCF_000186445',
#  'GCF_006739205',
#  'GCF_001457635',
#  'GCF_002811175',
#  'GCF_000154225',
#  'GCF_001883995',
#  'GCF_000012825',
#  '',
#  'GCF_002006445',
#  'GCF_000008565',
#  'GCF_000392875',
#  'GCF_001542625',
#  'GCF_900478295',
#  'GCF_000014425',
#  'GCF_900187225',
#  'GCF_000016525',
#  'GCF_900638555',
#  'GCF_003030305',
#  'GCF_001457615',
#  'GCF_000012905',
#  'GCF_001027105',
#  'GCF_006742205',
#  'GCF_000186445',
#  'GCF_006739205',
#  'GCF_001457635',
#  'GCF_000265425',
#  'GCF_000011325',
#  'GCF_000092985',
#  'GCF_000143845',
#  'GCF_000092825',
#  'GCF_000325705',
#  'GCF_000092125',
#  'GCF_000013285',
#  'GCF_000015865',
#  'GCF_000255115',
#  'GCF_000231385',
#  'GCF_000233715',
#  'GCF_002055535',
#  'GCF_000227705',
#  'GCF_002950215',
#  'GCF_000242255',
#  'GCF_000023785',
#  'GCF_000327065',
#  'GCF_000252995',
#  'GCF_000018625',
#  'GCF_000143985',
#  'GCF_000235405',
#  'GCF_000025905',
#  'GCA_000328525',
#  'GCF_000230715',
#  'GCF_000328685',
#  'GCF_002811175',
#  'GCF_000154225',
#  'GCF_001883995',
#  'GCF_000012825',
#  'GCF_002006445',
#  'GCF_000008565',
#  'GCF_000392875',
#  'GCF_001542625',
#  'GCF_900478295',
#  'GCF_000014425',
#  'GCF_900187225',
#  'GCF_900638555',
#  'GCF_003030305',
#  'GCF_001457615',
#  'GCF_000012905',
#  'GCF_001027105',
#  'GCF_006742205',
#  'GCF_000186445',
#  'GCF_006739205',
#  'GCF_001457635']

# %%
df_joined['assembly_in_db'] = df_joined['mapping_genome'] == np.array([_[0] for _ in df_joined['database_accession'].str.split('.')])

# %%
df_joined.groupby('dataset')['assembly_in_db'].sum()
# Out:
# dataset
# dual_index        4.0
# gis_20            9.0
# hmp_even          5.0
# hmp_staggered     5.0
# mbarc_26         23.0
# zymo_even         0.0
# zymo_log          0.0
# Name: assembly_in_db, dtype: float64
