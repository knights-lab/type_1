# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import seaborn as sns

from scipy.stats import pearsonr

sns.set_style("darkgrid")
np.random.seed(930525)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 200)

warnings.simplefilter('once')

# %matplotlib inline
# %load_ext watermark
# %watermark --iversions
# Out:
# numpy   1.18.4
# seaborn 0.10.1
# pandas  1.0.4

# %%
import requests

from io import StringIO

# %%
from collections import defaultdict

url = requests.get('https://docs.google.com/spreadsheets/d/1OYgLNTSd1BvFyGk9ps6xEaEk1KGoPx5VIgb_awHUXR4/export?format=csv')
csv_raw = StringIO(url.text)
df_truth = pd.read_csv(csv_raw, engine="python")

inf_tax_file = "/mnt/btrfs/data/gtdb_95/gtdb_genomes_reps_r95/r95.gtdb.tax"

# %%
ins_database = []
database_accessions = []

for accession in df_truth.gen_assembly_accession:
    in_database = False
    database_accession = ""
    if str(accession).startswith("GCF"):
        results = !rg {accession} {inf_tax_file}
        results_2 = !rg {accession.replace("GCF", "GCA")} {inf_tax_file}
        results = results + results_2
        if len(results) == 1:
            in_database = True
            database_accession = results[0].split("\t")[0]
    ins_database.append(in_database)
    database_accessions.append(database_accession)

# %%
df_truth['database_accessions'] = database_accessions
df_truth['in_database'] = ins_database

# %%
accessions_to_download = set(df_truth.loc[~df_truth['in_database'], 'download_names'])

# %%
accessions_to_download.remove(np.nan)

# %%
accessions_to_download
# Out:
# {'GCF_000005845',
#  'GCF_000006785',
#  'GCF_000006885',
#  'GCF_000007265',
#  'GCF_000007465',
#  'GCF_000007645',
#  'GCF_000008005',
#  'GCF_000008345',
#  'GCF_000010005',
#  'GCF_000016305',
#  'GCF_000016965',
#  'GCF_000153625',
#  'GCF_000172575',
#  'GCF_000174395',
#  'GCF_000182965',
#  'GCF_000191785',
#  'GCF_000196035',
#  'GCF_000307795',
#  'GCF_000349975',
#  'GCF_000377685',
#  'GCF_000743055',
#  'GCF_001077675',
#  'GCF_003324715',
#  'GCF_008329785',
#  'GCF_009873455',
#  'Neisseria_meningitidis_ATCC_BAA_335.fasta',
#  'Pseudomonas_aeruginosa_ATCC_47085.fasta',
#  'Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718.fasta',
#  'bsubtilis_pb.fasta',
#  'cneoformans_ont.fasta',
#  'ecoli_pb.fasta',
#  'efaecalis_pb.fasta',
#  'lfermentum_ontlumina.fasta',
#  'lmonocytogenes_pb.fasta',
#  'paeruginosa_pb.fasta',
#  'saureus_pb.fasta',
#  'scerevisiae_pb.fasta',
#  'senterica_pb.fasta'}

# %%
strains_folder = "/mnt/btrfs/data/type_1/strains"
for file in accessions_to_download:
    if file.endswith(".fasta"):
        if file.lower() == file:
            # !wget https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/{file} -O {strains_folder}/{file}
# Out:
# --2021-02-24 17:18:27--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/cneoformans_ont.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27515738 (26M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/cneoformans_ont.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]  26.24M  97.4MB/s    in 0.3s
#
# 2021-02-24 17:18:28 (97.4 MB/s) - ‘/mnt/btrfs/data/type_1/strains/cneoformans_ont.fasta’ saved [27515738/27515738]
#
# --2021-02-24 17:18:28--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/saureus_pb.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2832183 (2.7M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/saureus_pb.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]   2.70M  --.-KB/s    in 0.06s
#
# 2021-02-24 17:18:28 (48.5 MB/s) - ‘/mnt/btrfs/data/type_1/strains/saureus_pb.fasta’ saved [2832183/2832183]
#
# --2021-02-24 17:18:28--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/scerevisiae_pb.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12977524 (12M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/scerevisiae_pb.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]  12.38M  --.-KB/s    in 0.1s
#
# 2021-02-24 17:18:29 (86.4 MB/s) - ‘/mnt/btrfs/data/type_1/strains/scerevisiae_pb.fasta’ saved [12977524/12977524]
#
# --2021-02-24 17:18:29--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/senterica_pb.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4933063 (4.7M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/senterica_pb.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]   4.70M  --.-KB/s    in 0.08s
#
# 2021-02-24 17:18:29 (59.2 MB/s) - ‘/mnt/btrfs/data/type_1/strains/senterica_pb.fasta’ saved [4933063/4933063]
#
# --2021-02-24 17:18:29--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/bsubtilis_pb.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4159113 (4.0M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/bsubtilis_pb.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]   3.97M  --.-KB/s    in 0.07s
#
# 2021-02-24 17:18:30 (58.0 MB/s) - ‘/mnt/btrfs/data/type_1/strains/bsubtilis_pb.fasta’ saved [4159113/4159113]
#
# --2021-02-24 17:18:30--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/lmonocytogenes_pb.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3063014 (2.9M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/lmonocytogenes_pb.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]   2.92M  --.-KB/s    in 0.06s
#
# 2021-02-24 17:18:30 (50.2 MB/s) - ‘/mnt/btrfs/data/type_1/strains/lmonocytogenes_pb.fasta’ saved [3063014/3063014]
#
# --2021-02-24 17:18:30--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/ecoli_pb.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4976745 (4.7M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/ecoli_pb.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]   4.75M  --.-KB/s    in 0.08s
#
# 2021-02-24 17:18:31 (62.2 MB/s) - ‘/mnt/btrfs/data/type_1/strains/ecoli_pb.fasta’ saved [4976745/4976745]
#
# --2021-02-24 17:18:31--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/lfermentum_ontlumina.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1924545 (1.8M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/lfermentum_ontlumina.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]   1.83M  --.-KB/s    in 0.04s
#
# 2021-02-24 17:18:31 (42.6 MB/s) - ‘/mnt/btrfs/data/type_1/strains/lfermentum_ontlumina.fasta’ saved [1924545/1924545]
#
# --2021-02-24 17:18:31--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/paeruginosa_pb.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6925156 (6.6M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/paeruginosa_pb.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]   6.60M  --.-KB/s    in 0.09s
#
# 2021-02-24 17:18:31 (70.1 MB/s) - ‘/mnt/btrfs/data/type_1/strains/paeruginosa_pb.fasta’ saved [6925156/6925156]
#
# --2021-02-24 17:18:32--  https://raw.githubusercontent.com/al-mcintyre/mCaller_analysis_scripts/master/assemblies/efaecalis_pb.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2913357 (2.8M) [text/plain]
# Saving to: ‘/mnt/btrfs/data/type_1/strains/efaecalis_pb.fasta’
#
# /mnt/btrfs/data/typ 100%[===================>]   2.78M  --.-KB/s    in 0.06s
#
# 2021-02-24 17:18:32 (43.9 MB/s) - ‘/mnt/btrfs/data/type_1/strains/efaecalis_pb.fasta’ saved [2913357/2913357]

# %%
strains_folder = "/mnt/btrfs/data/type_1/strains"
for file in accessions_to_download:
    if file.startswith("GCF"):
        file = file.replace("GCF", "GCA")
        print(file)
        # !enaDataGet -f fasta {file} -d {strains_folder}
        # !mv {strains_folder}/{file}/assembled-molecule.fasta {strains_folder}/{file}.fna
        # !rm -rf {strains_folder}/{file}
# Out:
# GCA_000005845
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000008345
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000349975
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000196035
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000006885
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000007465
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000007645
# fetching 7 sequences: assembled-molecule
# downloaded 7 of 7 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000191785
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000007265
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_003324715
# fetching 6 sequences: assembled-molecule
# downloaded 6 of 6 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000174395
# fetching 4 sequences: assembled-molecule
# downloaded 4 of 4 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000016965
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000172575
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000010005
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_001077675
# fetching 2 sequences: assembled-molecule
# downloaded 2 of 2 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_008329785
# fetching 4 sequences: assembled-molecule
# downloaded 4 of 4 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000307795
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000182965
# fetching 8 sequences: assembled-molecule
# downloaded 8 of 8 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000743055
# fetching 2 sequences: assembled-molecule
# downloaded 2 of 2 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000016305
# fetching 6 sequences: assembled-molecule
# downloaded 6 of 6 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_009873455
# fetching 2 sequences: assembled-molecule
# downloaded 2 of 2 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000006785
# fetching 1 sequences: assembled-molecule
# downloaded 1 of 1 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000377685
# no sequences: assembled-molecule
# no sequences: unlocalised-scaffold
# fetching 46 sequences: unplaced-scaffold
# downloaded 46 of 46 sequences
# no sequences: patch
# Completed
# mv: cannot stat '/mnt/btrfs/data/type_1/strains/GCA_000377685/assembled-molecule.fasta': No such file or directory
# GCA_000008005
# fetching 2 sequences: assembled-molecule
# downloaded 2 of 2 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed
# GCA_000153625
# fetching 2 sequences: assembled-molecule
# downloaded 2 of 2 sequences
# no sequences: unlocalised-scaffold
# no sequences: unplaced-scaffold
# no sequences: patch
# Completed

# %%
accessions_to_download
# Out:
# {'GCF_000005845',
#  'GCF_000006785',
#  'GCF_000006885',
#  'GCF_000007265',
#  'GCF_000007465',
#  'GCF_000007645',
#  'GCF_000008005',
#  'GCF_000008345',
#  'GCF_000010005',
#  'GCF_000016305',
#  'GCF_000016965',
#  'GCF_000153625',
#  'GCF_000172575',
#  'GCF_000174395',
#  'GCF_000182965',
#  'GCF_000191785',
#  'GCF_000196035',
#  'GCF_000307795',
#  'GCF_000349975',
#  'GCF_000377685',
#  'GCF_000743055',
#  'GCF_001077675',
#  'GCF_003324715',
#  'GCF_008329785',
#  'GCF_009873455',
#  'Neisseria_meningitidis_ATCC_BAA_335.fasta',
#  'Pseudomonas_aeruginosa_ATCC_47085.fasta',
#  'Staphylococcus_aureus_subsp_aureus_ATCC_BAA_1718.fasta',
#  'bsubtilis_pb.fasta',
#  'cneoformans_ont.fasta',
#  'ecoli_pb.fasta',
#  'efaecalis_pb.fasta',
#  'lfermentum_ontlumina.fasta',
#  'lmonocytogenes_pb.fasta',
#  'paeruginosa_pb.fasta',
#  'saureus_pb.fasta',
#  'scerevisiae_pb.fasta',
#  'senterica_pb.fasta'}

# %%
def read_fasta(fh):
    """
    :return: tuples of (title, seq)
    """
    title = ""
    data = ""
    for line in fh:
        if line[0] == ">":
            if title:
                yield title.strip(), data
            title = line[1:]
            data = ''
        else:
            data += line.strip()
    if not title:
        yield None
    yield title.strip(), data

# %%
# ?os.mkdir
# Out:
# Signature: os.mkdir(path, mode=511, *, dir_fd=None)
# Docstring:
# Create a directory.
#
# If dir_fd is not None, it should be a file descriptor open to a directory,
#   and path should be relative; path will then be relative to that directory.
# dir_fd may not be implemented on your platform.
#   If it is unavailable, using it will raise a NotImplementedError.
#
# The mode argument is ignored on Windows.
# Type:      builtin_function_or_method

# %%
from glob import glob
import os

out_strains_folder = "/mnt/btrfs/data/type_1/strains_lin"

os.makedirs(out_strains_folder, exist_ok=True)

for file in glob(f"{strains_folder}/*"):
    with open(file) as inf:
        outf = os.path.join(out_strains_folder, ".".join(os.path.basename(file).split(".")[:-1]) + ".lin.noplasmid.fna")
        with open(outf, "w") as outfile:
            for header, seq in read_fasta(inf):
                if not "plasmid" in header:
                    outfile.write(f">{header}\n{seq}\n")

# %%
# !grep "GCF_001457555" "/mnt/btrfs/data/gtdb_95/gtdb_genomes_reps_r95/r95.gtdb.tax"
# Out:
# GCF_001457555.1	k__Bacteria;p__Fusobacteriota;c__Fusobacteriia;o__Fusobacteriales;f__Fusobacteriaceae;g__Fusobacterium;s__Fusobacterium_polymorphum
