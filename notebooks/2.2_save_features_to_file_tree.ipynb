# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import seaborn as sns

from scipy.stats import pearsonr

sns.set_style("darkgrid")
np.random.seed(930525)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 200)

warnings.simplefilter('once')

# %matplotlib inline
# %load_ext watermark
# %watermark --iversions
# Out:
# pandas  1.1.4
# numpy   1.18.4
# seaborn 0.10.1

# %%
import pandas as pd
import requests

from io import StringIO

# %%
from collections import defaultdict

url = requests.get('https://docs.google.com/spreadsheets/d/1KO_wGiEagJ8PMO2BzSDI1IXHYO4RHZMMSWXlT48peiQ/export?format=csv')
csv_raw = StringIO(url.text)
df_truth = pd.read_csv(csv_raw)

inf_tax_file = "/mnt/btrfs/data/gtdb_95/gtdb_genomes_reps_r95/r95.gtdb.tax"

# %% [markdown]
# # Building the true species dataset

# %%
df_tax = pd.read_csv(inf_tax_file, names=["assembly_accession", "tax"], sep="\t")

df_tax["species"] = [";".join(_.split(";")[:7]) for _ in df_tax.tax]
df_tax["genus"] = [";".join(_.split(";")[:6]) for _ in df_tax.tax]
df_tax["family"] = [";".join(_.split(";")[:5]) for _ in df_tax.tax]

# %%
accession_to_genus = dict()
for t in df_tax.itertuples():
    accession_to_genus[t.assembly_accession] = t.genus.split(";")[-1]

# %%
dd = defaultdict(set)

dd_genus = defaultdict(set)
for group, df in df_truth.groupby('dataset'):
    mask_nan = df_truth['database_accession'].astype(str) == 'nan'
    
    for row in df.loc[mask_nan].itertuples():
        # get the genus of the nans
        dd_genus[group].add("g__" + row.name.replace("_", " ").split()[0])
        dd_genus[group].add("g__" + row.homotypic_synonym.replace("_", " ").split()[0])
    
    dd[group] = set(df.loc[~mask_nan, "database_accession"].values)

# %%
from glob import glob
import os

files = glob("/mnt/btrfs/data/type_1/species_mc/b6_split_by_sample/*.extra.tree.csv")

dfs = []
for file in files:
    name = '_'.join(os.path.basename(file).split('.')[:-4])
    if name == "test_sort":
        continue
    df = pd.read_csv(file, index_col = 0)
    df['dataset'] = name
    dfs.append(df)
df_type_1_features = pd.concat(dfs)
# Out:
# /home/bhillmann/.conda/envs/type_1/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (84,88,97,105,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /home/bhillmann/.conda/envs/type_1/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (84,88,97,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /home/bhillmann/.conda/envs/type_1/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (47,49,55,56,57,58,70,83,95,96,100,103,104,108,109) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /home/bhillmann/.conda/envs/type_1/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (70,83,95,96,100,103,104,108,109) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_type_1_features.shape
# Out:
# (140027, 133)

# %%
rows = []
for t in df_type_1_features.itertuples():
    if t.assembly_accession in dd[t.dataset]:
        rows.append(True)
    else:
        rows.append(False)
df_type_1_features["truth"] = rows

# %%
# list(df_type_1_features.columns)

# %%
mask_missing = []
for t in df_type_1_features.itertuples():
    genus = accession_to_genus[t.assembly_accession]
    mask_missing.append(genus in dd_genus[t.dataset])
df_type_1_features = df_type_1_features.loc[~np.array(mask_missing)]

# %%
df_type_1_features['truth'].sum()
# Out:
# 122

# %%
# mask_eubacterium = [_ in eubacteriums for _ in df_type_1_features['assembly_accession']]

# %%
df_type_1_features.groupby('truth').mean()
# Out:
#        tree_dist  tree_top_dist           hits  percent_coverage  \
# truth
# False   0.125182       1.930329    4989.363381          0.001572
# True    0.045831       1.377049  151816.450820          0.086042
#
#        mean_coverage  sd_coverage  percent_padded_coverage  \
# truth
# False       0.177328     2.604657                 0.002261
# True        5.959077    31.298903                 0.133718
#
#        mean_padded_coverage  sd_padded_coverage  percent_binned_coverage  ...  \
# truth                                                                     ...
# False              0.266959            3.824381                 0.002928  ...
# True               9.599308           46.275548                 0.175852  ...
#
#        tree_gf_mean_scaffold_length  tree_gf_n50_contigs  \
# truth
# False                  8.059970e+05         1.094047e+06
# True                   2.212078e+06         2.763453e+06
#
#        tree_gf_n50_scaffolds  tree_gf_protein_count  tree_gf_scaffold_count  \
# truth
# False           1.250359e+06            3818.663117               76.265308
# True            2.922896e+06            3310.090164               13.737705
#
#        tree_gf_ssu_count  tree_gf_total_gap_length  tree_gf_trna_aa_count  \
# truth
# False           2.158435               9812.524550              19.337907
# True            4.311475               5892.532787              19.581967
#
#        tree_gf_trna_count  tree_gf_trna_selenocysteine_count
# truth
# False           51.751752                           0.161089
# True            59.286885                           0.139344
#
# [2 rows x 102 columns]

# %%
df_type_1_features.groupby('dataset').mean()
# Out:
#                tree_dist  tree_top_dist          hits  percent_coverage  \
# dataset
# dual_index      0.120691       1.989008    108.931851          0.001763
# gis_20          0.118900       1.896629  19213.013666          0.002178
# hmp_even        0.132927       1.831895   1205.671267          0.002222
# hmp_staggered   0.132350       1.850019    664.930262          0.001119
# mbarc_26        0.116898       2.056123   6640.071598          0.002374
# zymo_even       0.122589       1.984238    625.484874          0.001166
# zymo_log        0.126145       1.982295   8035.484096          0.000805
#
#                mean_coverage  sd_coverage  percent_padded_coverage  \
# dataset
# dual_index          0.005549     0.052780                 0.002234
# gis_20              0.587345    11.423644                 0.002844
# hmp_even            0.027150     0.670012                 0.003703
# hmp_staggered       0.013075     0.456796                 0.002148
# mbarc_26            0.445560     1.222147                 0.002614
# zymo_even           0.029422     0.303774                 0.001548
# zymo_log            0.252670     3.925084                 0.001280
#
#                mean_padded_coverage  sd_padded_coverage  \
# dataset
# dual_index                 0.006904            0.071412
# gis_20                     0.894045           15.995214
# hmp_even                   0.075910            1.370516
# hmp_staggered              0.042195            0.998040
# mbarc_26                   0.416823            1.181332
# zymo_even                  0.035656            0.372526
# zymo_log                   0.515691            6.302995
#
#                percent_binned_coverage  ...  tree_gf_n50_contigs  \
# dataset                                 ...
# dual_index                    0.002870  ...         1.129564e+06
# gis_20                        0.003692  ...         1.126497e+06
# hmp_even                      0.004653  ...         1.036182e+06
# hmp_staggered                 0.002964  ...         1.057824e+06
# mbarc_26                      0.003119  ...         1.135078e+06
# zymo_even                     0.002037  ...         1.106914e+06
# zymo_log                      0.001824  ...         1.110680e+06
#
#                tree_gf_n50_scaffolds  tree_gf_protein_count  \
# dataset
# dual_index              1.294797e+06            3807.313737
# gis_20                  1.277080e+06            3914.881261
# hmp_even                1.183016e+06            3798.242926
# hmp_staggered           1.207405e+06            3821.154354
# mbarc_26                1.306175e+06            3898.536280
# zymo_even               1.267416e+06            3743.073659
# zymo_log                1.269649e+06            3750.678970
#
#                tree_gf_scaffold_count  tree_gf_ssu_count  \
# dataset
# dual_index                  69.550468           2.265561
# gis_20                      77.134425           2.143943
# hmp_even                    83.113132           2.005308
# hmp_staggered               81.732126           2.043972
# mbarc_26                    79.262254           2.324745
# zymo_even                   69.400121           2.226796
# zymo_log                    69.803925           2.229324
#
#                tree_gf_total_gap_length  tree_gf_trna_aa_count  \
# dataset
# dual_index                 10889.223855              19.431568
# gis_20                      6620.545411              19.360842
# hmp_even                    9276.677129              19.196538
# hmp_staggered               9402.177458              19.252472
# mbarc_26                   12627.015178              19.385977
# zymo_even                  10587.274386              19.409942
# zymo_log                   10524.154483              19.405714
#
#                tree_gf_trna_count  tree_gf_trna_selenocysteine_count     truth
# dataset
# dual_index              52.481377                           0.155392  0.001193
# gis_20                  51.800808                           0.162767  0.001010
# hmp_even                50.275467                           0.163720  0.000969
# hmp_staggered           50.632297                           0.167380  0.000998
# mbarc_26                54.081964                           0.177699  0.001925
# zymo_even               52.195089                           0.148348  0.000485
# zymo_log                52.059537                           0.152263  0.000480
#
# [7 rows x 103 columns]

# %%
list(df_type_1_features.columns)
# Out:
# ['assembly_accession',
#  'tree_closest_assembly_accession',
#  'tree_dist',
#  'tree_top_dist',
#  'hits',
#  'percent_coverage',
#  'mean_coverage',
#  'sd_coverage',
#  'percent_padded_coverage',
#  'mean_padded_coverage',
#  'sd_padded_coverage',
#  'percent_binned_coverage',
#  'mean_binned_coverage',
#  'sd_binned_coverage',
#  'expected_percent_coverage',
#  'shannon_entropy',
#  'percent_max_uncovered_region',
#  'largest_pileup',
#  'largest_padded_pileup',
#  'largest_binned_pileup',
#  'gc_content',
#  'total_genome_length',
#  'ungapped_genome_length',
#  'num_n_groups',
#  'consecutive_ns',
#  'gf_accession',
#  'gf_ambiguous_bases',
#  'gf_checkm_completeness',
#  'gf_checkm_contamination',
#  'gf_checkm_marker_count',
#  'gf_checkm_marker_lineage',
#  'gf_checkm_marker_set_count',
#  'gf_checkm_strain_heterogeneity',
#  'gf_coding_bases',
#  'gf_coding_density',
#  'gf_contig_count',
#  'gf_gc_count',
#  'gf_gc_percentage',
#  'gf_genome_size',
#  'gf_gtdb_genome_representative',
#  'gf_gtdb_representative',
#  'gf_gtdb_taxonomy',
#  'gf_gtdb_type_designation',
#  'gf_gtdb_type_designation_sources',
#  'gf_gtdb_type_species_of_genus',
#  'gf_l50_contigs',
#  'gf_l50_scaffolds',
#  'gf_longest_contig',
#  'gf_longest_scaffold',
#  'gf_lsu_23s_contig_len',
#  'gf_lsu_23s_count',
#  'gf_lsu_23s_length',
#  'gf_lsu_23s_query_id',
#  'gf_lsu_5s_contig_len',
#  'gf_lsu_5s_count',
#  'gf_lsu_5s_length',
#  'gf_lsu_5s_query_id',
#  'gf_lsu_silva_23s_blast_align_len',
#  'gf_lsu_silva_23s_blast_bitscore',
#  'gf_lsu_silva_23s_blast_evalue',
#  'gf_lsu_silva_23s_blast_perc_identity',
#  'gf_lsu_silva_23s_blast_subject_id',
#  'gf_lsu_silva_23s_taxonomy',
#  'gf_mean_contig_length',
#  'gf_mean_scaffold_length',
#  'gf_mimag_high_quality',
#  'gf_mimag_low_quality',
#  'gf_mimag_medium_quality',
#  'gf_n50_contigs',
#  'gf_n50_scaffolds',
#  'gf_ncbi_assembly_level',
#  'gf_ncbi_assembly_name',
#  'gf_ncbi_assembly_type',
#  'gf_ncbi_bioproject',
#  'gf_ncbi_biosample',
#  'gf_ncbi_contig_count',
#  'gf_ncbi_contig_n50',
#  'gf_ncbi_country',
#  'gf_ncbi_date',
#  'gf_ncbi_genbank_assembly_accession',
#  'gf_ncbi_genome_category',
#  'gf_ncbi_genome_representation',
#  'gf_ncbi_isolate',
#  'gf_ncbi_isolation_source',
#  'gf_ncbi_lat_lon',
#  'gf_ncbi_molecule_count',
#  'gf_ncbi_ncrna_count',
#  'gf_ncbi_organism_name',
#  'gf_ncbi_protein_count',
#  'gf_ncbi_refseq_category',
#  'gf_ncbi_rrna_count',
#  'gf_ncbi_scaffold_count',
#  'gf_ncbi_scaffold_l50',
#  'gf_ncbi_scaffold_n50',
#  'gf_ncbi_scaffold_n75',
#  'gf_ncbi_scaffold_n90',
#  'gf_ncbi_seq_rel_date',
#  'gf_ncbi_spanned_gaps',
#  'gf_ncbi_species_taxid',
#  'gf_ncbi_ssu_count',
#  'gf_ncbi_strain_identifiers',
#  'gf_ncbi_submitter',
#  'gf_ncbi_taxid',
#  'gf_ncbi_taxonomy',
#  'gf_ncbi_taxonomy_unfiltered',
#  'gf_ncbi_total_gap_length',
#  'gf_ncbi_total_length',
#  'gf_ncbi_translation_table',
#  'gf_ncbi_trna_count',
#  'gf_ncbi_type_material_designation',
#  'gf_ncbi_ungapped_length',
#  'gf_ncbi_unspanned_gaps',
#  'gf_ncbi_wgs_master',
#  'gf_protein_count',
#  'gf_scaffold_count',
#  'gf_ssu_contig_len',
#  'gf_ssu_count',
#  'gf_ssu_gg_blast_align_len',
#  'gf_ssu_gg_blast_bitscore',
#  'gf_ssu_gg_blast_evalue',
#  'gf_ssu_gg_blast_perc_identity',
#  'gf_ssu_gg_blast_subject_id',
#  'gf_ssu_gg_taxonomy',
#  'gf_ssu_length',
#  'gf_ssu_query_id',
#  'gf_ssu_silva_blast_align_len',
#  'gf_ssu_silva_blast_bitscore',
#  'gf_ssu_silva_blast_evalue',
#  'gf_ssu_silva_blast_perc_identity',
#  'gf_ssu_silva_blast_subject_id',
#  'gf_ssu_silva_taxonomy',
#  'gf_total_gap_length',
#  'gf_trna_aa_count',
#  'gf_trna_count',
#  'gf_trna_selenocysteine_count',
#  'tree_hits',
#  'tree_percent_coverage',
#  'tree_mean_coverage',
#  'tree_sd_coverage',
#  'tree_percent_padded_coverage',
#  'tree_mean_padded_coverage',
#  'tree_sd_padded_coverage',
#  'tree_percent_binned_coverage',
#  'tree_mean_binned_coverage',
#  'tree_sd_binned_coverage',
#  'tree_expected_percent_coverage',
#  'tree_shannon_entropy',
#  'tree_percent_max_uncovered_region',
#  'tree_largest_pileup',
#  'tree_largest_padded_pileup',
#  'tree_largest_binned_pileup',
#  'tree_gc_content',
#  'tree_total_genome_length',
#  'tree_ungapped_genome_length',
#  'tree_num_n_groups',
#  'tree_consecutive_ns',
#  'tree_gf_accession',
#  'tree_gf_ambiguous_bases',
#  'tree_gf_checkm_completeness',
#  'tree_gf_checkm_contamination',
#  'tree_gf_checkm_marker_count',
#  'tree_gf_checkm_marker_lineage',
#  'tree_gf_checkm_marker_set_count',
#  'tree_gf_checkm_strain_heterogeneity',
#  'tree_gf_coding_bases',
#  'tree_gf_coding_density',
#  'tree_gf_contig_count',
#  'tree_gf_gc_count',
#  'tree_gf_gc_percentage',
#  'tree_gf_genome_size',
#  'tree_gf_gtdb_genome_representative',
#  'tree_gf_gtdb_representative',
#  'tree_gf_gtdb_taxonomy',
#  'tree_gf_gtdb_type_designation',
#  'tree_gf_gtdb_type_designation_sources',
#  'tree_gf_gtdb_type_species_of_genus',
#  'tree_gf_l50_contigs',
#  'tree_gf_l50_scaffolds',
#  'tree_gf_longest_contig',
#  'tree_gf_longest_scaffold',
#  'tree_gf_lsu_23s_contig_len',
#  'tree_gf_lsu_23s_count',
#  'tree_gf_lsu_23s_length',
#  'tree_gf_lsu_23s_query_id',
#  'tree_gf_lsu_5s_contig_len',
#  'tree_gf_lsu_5s_count',
#  'tree_gf_lsu_5s_length',
#  'tree_gf_lsu_5s_query_id',
#  'tree_gf_lsu_silva_23s_blast_align_len',
#  'tree_gf_lsu_silva_23s_blast_bitscore',
#  'tree_gf_lsu_silva_23s_blast_evalue',
#  'tree_gf_lsu_silva_23s_blast_perc_identity',
#  'tree_gf_lsu_silva_23s_blast_subject_id',
#  'tree_gf_lsu_silva_23s_taxonomy',
#  'tree_gf_mean_contig_length',
#  'tree_gf_mean_scaffold_length',
#  'tree_gf_mimag_high_quality',
#  'tree_gf_mimag_low_quality',
#  'tree_gf_mimag_medium_quality',
#  'tree_gf_n50_contigs',
#  'tree_gf_n50_scaffolds',
#  'tree_gf_ncbi_assembly_level',
#  'tree_gf_ncbi_assembly_name',
#  'tree_gf_ncbi_assembly_type',
#  'tree_gf_ncbi_bioproject',
#  'tree_gf_ncbi_biosample',
#  'tree_gf_ncbi_contig_count',
#  'tree_gf_ncbi_contig_n50',
#  'tree_gf_ncbi_country',
#  'tree_gf_ncbi_date',
#  'tree_gf_ncbi_genbank_assembly_accession',
#  'tree_gf_ncbi_genome_category',
#  'tree_gf_ncbi_genome_representation',
#  'tree_gf_ncbi_isolate',
#  'tree_gf_ncbi_isolation_source',
#  'tree_gf_ncbi_lat_lon',
#  'tree_gf_ncbi_molecule_count',
#  'tree_gf_ncbi_ncrna_count',
#  'tree_gf_ncbi_organism_name',
#  'tree_gf_ncbi_protein_count',
#  'tree_gf_ncbi_refseq_category',
#  'tree_gf_ncbi_rrna_count',
#  'tree_gf_ncbi_scaffold_count',
#  'tree_gf_ncbi_scaffold_l50',
#  'tree_gf_ncbi_scaffold_n50',
#  'tree_gf_ncbi_scaffold_n75',
#  'tree_gf_ncbi_scaffold_n90',
#  'tree_gf_ncbi_seq_rel_date',
#  'tree_gf_ncbi_spanned_gaps',
#  'tree_gf_ncbi_species_taxid',
#  'tree_gf_ncbi_ssu_count',
#  'tree_gf_ncbi_strain_identifiers',
#  'tree_gf_ncbi_submitter',
#  'tree_gf_ncbi_taxid',
#  'tree_gf_ncbi_taxonomy',
#  'tree_gf_ncbi_taxonomy_unfiltered',
#  'tree_gf_ncbi_total_gap_length',
#  'tree_gf_ncbi_total_length',
#  'tree_gf_ncbi_translation_table',
#  'tree_gf_ncbi_trna_count',
#  'tree_gf_ncbi_type_material_designation',
#  'tree_gf_ncbi_ungapped_length',
#  'tree_gf_ncbi_unspanned_gaps',
#  'tree_gf_ncbi_wgs_master',
#  'tree_gf_protein_count',
#  'tree_gf_scaffold_count',
#  'tree_gf_ssu_contig_len',
#  'tree_gf_ssu_count',
#  'tree_gf_ssu_gg_blast_align_len',
#  'tree_gf_ssu_gg_blast_bitscore',
#  'tree_gf_ssu_gg_blast_evalue',
#  'tree_gf_ssu_gg_blast_perc_identity',
#  'tree_gf_ssu_gg_blast_subject_id',
#  'tree_gf_ssu_gg_taxonomy',
#  'tree_gf_ssu_length',
#  'tree_gf_ssu_query_id',
#  'tree_gf_ssu_silva_blast_align_len',
#  'tree_gf_ssu_silva_blast_bitscore',
#  'tree_gf_ssu_silva_blast_evalue',
#  'tree_gf_ssu_silva_blast_perc_identity',
#  'tree_gf_ssu_silva_blast_subject_id',
#  'tree_gf_ssu_silva_taxonomy',
#  'tree_gf_total_gap_length',
#  'tree_gf_trna_aa_count',
#  'tree_gf_trna_count',
#  'tree_gf_trna_selenocysteine_count',
#  'dataset',
#  'truth']

# %%
df_type_1_features.reset_index(drop=True).to_csv("../data/strains.dataset.tree.csv")
